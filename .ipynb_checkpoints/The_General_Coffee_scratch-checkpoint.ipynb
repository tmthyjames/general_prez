# %%
# to get shape files -> download cb_2015_us_zcta510_500k from census
# shp2pgsql -s SRID cb_2015_us_zcta510_500k.shp | psql econ

# %%
# indexes
# create index ix_zip on zip_to_naics using btree (zip);
# create index ix_zip_naics on zip_to_naics using btree (naics);

# create index ix_zip_data_Id2 on zip_data using btree ("Id2");

# create index ix_zip_data2_Id on zip_data2 using btree ("Id2");

# create index ix_zip_data3_Id2 on zip_data3 using btree ("Id2");

# create index ix_sb_stores_zipcode on sb_stores using btree (zipcode);

# create index ix_zbp_ZIP__ZIPcode on zbp using btree ("ZIP__ZIPcode");

# vacuum analyze zip_to_naics, zip_data, zip_data2, sb_stores;
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-67ce08011de1> in <module>()
#       6 # create index ix_sb_stores_zipcode on sb_stores using btree (zipcode);
#       7
# ----> 8 naics
#
# NameError: name 'naics' is not defined

# %% [markdown]
# # create table with zip data and sb count
# CREATE TABLE zip_data_sb AS
#     select z.*,
#         count(sb."zipcode") over (
#             partition by sb.zipcode
#         ) as starbucks_count
#     from zip_data z
#     left join sb_stores sb on sb."zipcode" = z."Id2";

# %%
# %%sql DB=econ
# select (
#         select count(*)
#         from sb_stores
#         where "zipcode" = sb."zipcode"
#     ) as num_of_sb,
#
#     count(sb."zipcode") over (
#         partition by sb.zipcode
#     ) as num_of_sb_test,
#
#     *
# from zip_data z
# join zip_data2 z2 on z2."Id" = z."Id"
# join zip_data3 z3 on z3."Id" = z."Id"
# left join sb_stores sb on sb."zipcode" = z."Id2"
# join cb_2015_us_zcta510_500k c on c.geoid10::bigint = z."Id2"
# limit 10
# Out:
#         <style>
#         .input {
#             position:relative;
#         }
#         #childDiv28bc072e-bc75-401e-bd96-a077d676ac57 {
#             width: 90%;
#             position:absolute;
#         }
#         #table28bc072e-bc75-401e-bd96-a077d676ac57{
#             padding-top: 40px;
#         }
#         </style>
#         <div class="row" id="childDiv28bc072e-bc75-401e-bd96-a077d676ac57">
#             <div class="btn-group col-md-3">
#                 <button id="explain" title="Explain Analyze Graph" onclick="explain('__EXPLAIN_GRAPH__')" type="button" class="btn btn-info btn-sm"><p class="fa fa-code-fork fa-rotate-270"</p></button>
#                 <button id="explain" title="Explain Analyze" onclick="explain('__EXPLAIN__')" type="button" class="btn btn-info btn-sm"><p class="fa fa-info-circle"</p></button>
#                 <button type="button" title="Execute" onclick="run()" class="btn btn-success btn-sm"><p class="fa fa-play"></p></button>
#                 <button type="button" title="Execute and Return Data as Variable" onclick="getData()" class="btn btn-success btn-sm"><p class="">var</p></button>
#                 <button id="saveData28bc072e-bc75-401e-bd96-a077d676ac57" title="Save" class="btn btn-success btn-sm disabled" type="button"><p class="fa fa-save"</p></button>
#                 <button id="cancelQuery28bc072e-bc75-401e-bd96-a077d676ac57" title="Cancel Query" class="btn btn-danger btn-sm" type="button"><p class="fa fa-stop"</p></button>
#             </div>
#             <div id="engineButtons28bc072e-bc75-401e-bd96-a077d676ac57" class="btn-group col-md-4"></div>
#             <div id="tableData28bc072e-bc75-401e-bd96-a077d676ac57"></div>
#         </div>
#         <div class="table" id="table28bc072e-bc75-401e-bd96-a077d676ac57"></div>
#         <script type="text/Javascript">
#
#             (function($) {
#                 var MutationObserver = window.MutationObserver || window.WebKitMutationObserver || window.MozMutationObserver;
#
#                 $.fn.attrchange = function(callback) {
#                     if (MutationObserver) {
#                         var options = {
#                             subtree: false,
#                             attributes: true
#                         };
#
#                         var observer = new MutationObserver(function(mutations) {
#                             mutations.forEach(function(e) {
#                                 callback.call(e.target, e.attributeName);
#                             });
#                         });
#
#                         return this.each(function() {
#                             observer.observe(this, options);
#                         });
#
#                     }
#                 }
#             } )(jQuery);
#             $("#childDiv28bc072e-bc75-401e-bd96-a077d676ac57").parents('.code_cell').attrchange(function(attrName){
#                 if (attrName=='class'){
#                     if ($(this).hasClass('unselected')){
#                         $("#childDiv28bc072e-bc75-401e-bd96-a077d676ac57").find('button').each(function(i, obj){
#                             $(obj).addClass('disabled');
#                         });
#                     } else if ($(this).hasClass('selected')){
#                         $("#childDiv28bc072e-bc75-401e-bd96-a077d676ac57").find('button').each(function(i, obj){
#                             $(obj).removeClass('disabled');
#                         });
#                     }
#                 }
#             });
#
#
#
#             var engines = JSON.parse(`{"PRODALL": {"engine": "postgresql://phdba:RXBpJd8fH7BTUDZdO8qB@phteam-prod.ccmhg5j69wvw.us-east-1.rds.amazonaws.com:5432/", "caution_level": "danger", "order": 3}, "DATALAKE": {"engine": "postgresql://tim.dobbins:2F5HVimo@db.phdatalake.perceptionhealth.com/", "caution_level": "danger", "order": 4}, "PROD": {"engine": "postgresql://phdba:RXBpJd8fH7BTUDZdO8qB@phteam-prod.ccmhg5j69wvw.us-east-1.rds.amazonaws.com:5432/", "caution_level": "danger", "order": 2}, "LOCAL": {"engine": "postgresql://phdba:RXBpJd8fH7BTUDZdO8qB@localhost:5432/", "caution_level": "warning", "order": 0}, "DEV": {"engine": "postgresql://phTeam:4zHam9MLDC@db.dev.phteam.perceptionhealth.com/", "caution_level": "warning", "order": 1}}`);
#
#             var sortedEngineKeys = Object.keys(engines).sort(function(a,b){
#                 return engines[a].order - engines[b].order;
#             });
#
#             var sortedEngines = sortedEngineKeys.reduce(function(output, row, idx){
#                 engines[row]['key'] = row;
#                 output.push(engines[row]);
#                 return output;
#             }, []);
#
#             var engineButtons = '';
#             for (var engine in sortedEngines){
#                 var engineKey = sortedEngines[engine].key;
#                 var warningLabel = sortedEngines[engine].caution_level;
#                 engineButtons += '<button title="Switch Engine" onclick="switchEngines('+"'"+engineKey+"'"+')" class="btn btn-'+warningLabel+' btn-sm">'+engineKey+'</button>';
#             };
#
#            $("#engineButtons28bc072e-bc75-401e-bd96-a077d676ac57").append(engineButtons);
#
#            $("#cancelQuery28bc072e-bc75-401e-bd96-a077d676ac57").on('click', function(){
#                if ($("#cancelQuery28bc072e-bc75-401e-bd96-a077d676ac57").hasClass('disabled')){
#                    console.log('alread stopped or finished query...');
#                } else {
#                    cancelQuery("4b4a0c93-5be9-4bab-af39-765f58b5c162");
#                    //$("#cancelQuery28bc072e-bc75-401e-bd96-a077d676ac57").addClass('disabled')
#                }
#            });
#
#             function explain(gloVar){
#                 var command =  `__SQLCell_GLOBAL_VARS__.`+gloVar+` = True`;
#                 console.log(command);
#                 var kernel = IPython.notebook.kernel;
#                 kernel.execute(command);
#                 IPython.notebook.execute_cell();
#             };
#
#             function run(){
#                 IPython.notebook.execute_cell();
#                 $.get('/api/contents', function(data){
#                     console.log(data);
#                 });
#             };
#
#             function cancelQuery(applicationID){
#                 IPython.notebook.kernel.execute('__SQLCell_GLOBAL_VARS__().kill_last_pid_on_new_thread(__SQLCell_GLOBAL_VARS__.jupyter_id, "econ", "28bc072e-bc75-401e-bd96-a077d676ac57")',
#                     {
#                         iopub: {
#                             output: function(response) {
#                                 var $table = $("#table28bc072e-bc75-401e-bd96-a077d676ac57").parent();
#                                 console.log(response);
#                                 if (response.content && response.content.text){
#                                     $table.append('<h5 style="color:#d9534f;">'+response.content.text+'</h5>')
#                                 } else if (response.content && response.content.evalue){
#                                     $table.append('<h5 style="color:#d9534f;">'+response.content.evalue+'</h5>');
#                                 }
#                             }
#                         }
#                     },
#                     {
#                         silent: false,
#                         store_history: false,
#                         stop_on_error: true
#                     }
#                 );
#             };
#
#             function getData(){
#                 var command = `__SQLCell_GLOBAL_VARS__.__GETDATA__ = True`;
#                 var kernel = IPython.notebook.kernel;
#                 kernel.execute(command);
#                 IPython.notebook.execute_cell();
#             };
#
#             function saveData(data, filename){
#                 var path = $('#path').val() || './'
#                 var command = `__SQLCell_GLOBAL_VARS__.__SAVEDATA__, PATH = True,'`+path+`'`;
#                 var kernel = IPython.notebook.kernel;
#                 kernel.execute(command);
#                 //IPython.notebook.execut

# %% [markdown]
# # data import/clean up

# %%
import pandas as pd
from sqlalchemy import create_engine

engine = create_engine('postgresql://tdobbins:tdobbins@localhost/econ')

import pandas as pd

sb_stores = pd.read_csv('/Users/tdobbins/Downloads/the_general/StarbucksStores.csv')
zip_counties = pd.read_csv('/Users/tdobbins/Downloads/the_general/ZipCodeCounties.csv', encoding='latin1')
zip_data = pd.read_csv('/Users/tdobbins/Downloads/the_general/ZIPData.csv')
zip_data2 = pd.read_csv('/Users/tdobbins/Downloads/the_general/ZIPData2.csv')
zip_data3 = pd.read_csv('/Users/tdobbins/Downloads/the_general/ZIPData3.csv')

tables = [
    ('sb_stores', sb_stores), 
    ('zipcodes', zip_counties),
    ('zip_data', zip_data),
    ('zip_data2', zip_data2),
    ('zip_data3', zip_data3)
]

for table, df in tables:
    df.replace({'-|': ''}, regex=True).apply(lambda x: pd.to_numeric(x, errors='ignore')).to_sql(table, engine, if_exists='replace', index=True)
    
    
zbp = pd.read_csv('/Users/tdobbins/Downloads/zbp12-13totals.csv', header=None)
zbp.to_sql('zbp', engine, if_exists='replace', index=True)

zipcode_to_fips = pd.read_csv('/Users/tdobbins/Downloads/BP_2014_00CZ2/BP_2014_00CZ2.csv', header=1)

###################### models #####

import statsmodels.api as sm
# %matplotlib inline

path = '/Users/tdobbins/Desktop/zbp.csv'
sample = pd.read_csv(path)


#########################
# GLM model, results
#########################

admit_yn = sample.has_starbucks
score = sample.new_homes
# score = sample.GP5

score_with_intercept = sm.add_constant(score)

model = sm.GLM(admit_yn, score_with_intercept, family=sm.families.Binomial())
result = model.fit()

print result.summary()

import pylab as plt
from sklearn.metrics import roc_curve, auc
from sklearn import metrics
import numpy as np
from scipy import stats

admit_array = np.asarray(admit_yn)
pred = np.asarray(score)

# retrieve false-positive rates and true-positive rates
fpr, tpr, thresholds = metrics.roc_curve(admit_array, pred, pos_label=1)
metrics.auc(fpr, tpr)

#compute area under curve 
roc_auc = auc(fpr, tpr)

# plotting the ROC curve
roc_curve = plt.figure(figsize=(12,8))
plt.clf()
plt.plot(fpr, tpr, label='ROC curve (area = %0.3f)' % roc_auc)

# dashed line through the origin
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])

# labels and legend
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic curve')
plt.legend(loc="lower right")

############################## False positives for logit regression

logit = sm.Logit(sample['has_starbucks'], sample[['new_homes','hotels','HC03_VC88','shopping_centers']])
# fit the model
result = logit.fit()
print result.summary()

sample['predict'] = result.predict(sample[['new_homes','hotels','HC03_VC88','shopping_centers']])
predict = sample[['new_homes','hotels','HC03_VC88', 'HC03_VC96', 'shopping_centers', 'has_starbucks', 'predict', 'zip']]
predict[(predict.has_starbucks==0)&(predict.predict>0.55)].sort_values(['predict'], ascending=[0])

## Correlation matrix

import seaborn as sns
corr = df[['sq_miles', u'HC03_VC96', 'HC03_VC88', 
           'shopping_centers', 'new_homes', 'hotels', 
           'population_density', 'starbucks_count', 
           'airport_related', 'colleges', 'HC01_VC118', 
           u'HC01_VC03', u'HC01_VC103',]].corr()

plt.subplots(figsize=(13,10)) 
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)

# %%
data_dict = pd.read_excel('/Users/tdobbins/Downloads/the_general/Data Dictionary.xlsx', sheetname='ZipData')
data_dict.columns = ['index', 'field_name', 'field_value']

data_dict2 = pd.read_excel('/Users/tdobbins/Downloads/the_general/Data Dictionary.xlsx', sheetname='ZipData2')
data_dict2.columns = ['index', 'field_name', 'field_value']

data_dict3 = pd.read_excel('/Users/tdobbins/Downloads/the_general/Data Dictionary.xlsx', sheetname='ZipData3')
data_dict3.columns = ['index', 'field_name', 'field_value']

# %%
data_dict_all = pd.concat([data_dict, data_dict2, data_dict3])
del data_dict_all['index'] # remove index column, add new index during import

# %%
# data_dict_all.to_sql('data_dict', engine, if_exists='append', index=True)

# %%
import pandas as pd

sb_stores = pd.read_csv('/Users/tdobbins/Downloads/the_general/StarbucksStores.csv')
zip_counties = pd.read_csv('/Users/tdobbins/Downloads/the_general/ZipCodeCounties.csv', encoding='latin1')
zip_data = pd.read_csv('/Users/tdobbins/Downloads/the_general/ZIPData.csv')
zip_data2 = pd.read_csv('/Users/tdobbins/Downloads/the_general/ZIPData2.csv')
zip_data3 = pd.read_csv('/Users/tdobbins/Downloads/the_general/ZIPData3.csv')

# sb_stores['Zip'] = sb_stores['Zip'].astype(str)
# zip_counties['ZipCode'] = zip_counties['ZipCode'].astype(str)
sb_stores['zipcode'], sb_stores['zipcode_ex'] = sb_stores['Zip'].str.split('-').str

# %%
sb_stores
# Out:
#            Brand  Store Number                                 Name  \
# 10842  Starbucks  74640         Carrs-Ketchikan #1818
#
#       Ownership Type  Facility ID  \
# 0      Company Owned  18228
# 1      Licensed       9956
# 2      Licensed       10933
# 3      Company Owned  16980
# 4      Company Owned  17269
# 5      Company Owned  18462
# 6      Company Owned  18106
# 7      Company Owned  16075
# 8      Company Owned  12947
# 9      Licensed       6510
# 10     Company Owned  7942
# 11     Licensed       10152
# 12     Company Owned  11932
# 13     Licensed       87044
# 14     Licensed       6511
# 15     Company Owned  6835
# 16     Licensed       14413
# 17     Licensed       8490
# 18     Company Owned  8898
# 19     Company Owned  13579
# 20     Company Owned  7131
# 21     Company Owned  14501
# 22     Company Owned  12297
# 23     Licensed       66223
# 24     Company Owned  14500
# 25     Company Owned  6615
# 26     Licensed       11012
# 27     Company Owned  10506
# 28     Company Owned  15024
# 29     Company Owned  15876
# ...              ...    ...
# 10813  Company Owned  15931
# 10814  Licensed       10480
# 10815  Licensed       11465
# 10816  Licensed       13718
# 10817  Licensed       11778
# 10818  Licensed       11014
# 10819  Licensed       7606
# 10820  Licensed       6458
# 10821  Licensed       35537
# 10822  Licensed       13241
# 10823  Licensed       11524
# 10824  Company Owned  8129
# 10825  Licensed       20205
# 10826  Licensed       7890
# 10827  Licensed       10707
# 10828  Licensed       20034
# 10829  Licensed       12568
# 10830  Licensed       11510
# 10831  Licensed       8117
# 10832  Licensed       11509
# 10833  Licensed       9448
# 10834  Licensed       11450
# 10835  Licensed       14473
# 10836  Licensed       17562
# 10837  Licensed       7551
# 10838  Licensed       6854
# 10839  Licensed       15168
# 10840  Licensed       18694
# 10841  Licensed       17461
# 10842  Licensed       13769
#
#                                                                                         Features - Products  \
# 0      Lunch, Oven-warmed Food, Reserve Amenity
# 1      NaN
# 2      NaN
# 3      Lunch, Oven-warmed Food, Reserve Amenity, Sirena Espresso Machine
# 4      Lunch, Oven-warmed Food, Reserve Amenity
# 5      Lunch, Oven-warmed Food, Reserve Amenity, Sirena Espresso Machine
# 6      Lunch, Oven-warmed Food, Reserve Amenity
# 7      Clover Crafted Small Batch Coffee, Lunch, Oven-warmed Food, Reserve Amenity, Sirena Espresso Machine
# 8      Lunch, Oven-warmed Food, Sirena Espresso Machine
# 9      NaN
# 10     Lunch, Oven-warmed Food, Reserve Amenity, Sirena Espresso Machine
# 11     NaN
# 12     Lunch, Oven-warmed Food, Reserve Amenity, Sirena Espresso Machine
# 13     NaN
# 14     NaN
# 15     Lunch, Oven-warmed Food, Reserve Amenity
# 16     NaN
# 17     NaN
# 18     Lunch, Oven-warmed Food, Reserve Amenity, Sirena Espresso Machine
# 19     Clover Crafted Small Batch Coffee, Lunch, Oven-warmed Food, Reserve Amenity
# 20     Lunch, Oven-warmed Food, Reserve Amenity, Sirena Espresso Machine
# 21     Lunch, Oven-warmed Food, Reserve Amenity, Sirena Espresso Machine
# 22     Lunch, Oven-warmed Food, Reserve Amenity, Sirena Espresso Machine
# 23     NaN
# 24     Lunch, Sirena Espresso Machine
# 25     Lunch, Oven-warmed Food, Reserve Amenity
# 10816  2000 W Dimond Blvd                       NaN           Anchorage
# 10817  2300 Abbott Road                         NaN           Anchorage
# 10818  150 W 100th Ave Suite A                  NaN           Anchorage
# 10819  4000 W Dimond Blvd                       NaN           Anchorage
# 10820  Frontier Theater, Building 2             NaN           Fort Richardson
# 10821  1501 Huffman Rd                          NaN           Anchorage
# 10822  13401 Old Glenn Hwy                      NaN           Eagle River
# 10823  11409 Business Blvd                      NaN           Eagle River
# 10824  16707 Coronado Road                      100           Eagle River
# 10825  595 E Parks Hwy                          NaN           Wasilla
# 10826  1501 East Parks Highway                  NaN           Wasilla
# 10827  1801 E Parks Hwy                         NaN           Wasilla
# 10828  664 W Evergreen Ave                      NaN           Palmer
# 10829  650 N Cobb St                            NaN           Palmer
# 10830  2685 Mill Bay Rd                         NaN           Kodiak
# 10831  90 Sterling Hwy                          NaN           Homer
# 10832  44282 Sterling Hwy S                     NaN           Soldotna
# 10833  43843 Sterling Hwy                       NaN           Soldotna
# 10834  1907 Seward Hwy                          NaN           Seward
# 10835  30 College Rd                            NaN           Fairbanks
# 10836  930 Old Steese Hwy                       A             Fairbanks
# 10837  Bldg # 3703B                             NaN           Fort Wainwright
# 10838  3627 Airport Way (405R)                  NaN           Fairbanks
# 10839  3755 Airport Way                         NaN           Fairbanks
# 10840  303 Vintage Blvd                         NaN           Juneau
# 10841  8181 Old Glacier Hwy                     NaN           Juneau
# 10842  2417 Tongass Ave                         NaN           Ketchikan
#
#       State         Zip Country                          Coordinates  \
# 0      NH    03042-2224  US      (43.031873, -71.073203)
# 1      NH    03833-2105  US      (42.989763, -70.932044)
# 2      NH    03840-2438  US      (43.04871, -70.816345)
# 3      NH    03874-4512  US      (42.882128, -70.86808)
# 4      NH    03801-3228  US      (43.092318, -70.792327)
# 5      NH    03801-4011  US      (43.077086, -70.758064)
# 6      MA    01830-1413  US      (42.807206, -71.102071)
# 7      MA    01950-2571  US      (42.811138, -70.869501)
# 8      ME    3904        US      (43.111116, -70.734091)
# 9      MA    01832-1236  US      (42.786955, -71.115836)
# 10     NH    03820-2403  US      (43.221256, -70.888115)
# 11     NH    03878-1042  US      (43.232909, -70.8818)
# 12     MA    01844-7289  US      (42.744153230002, -71.157345224281)
# 13     NH    03079-3377  US      (42.764387, -71.216689)
# 14     MA    01844-7202  US      (42.741881, -71.160069)
# 15     NH    03103-4035  US      (42.960288, -71.438445)
# 16     NH    03103-7450  US      (42.92709763021, -71.446556926821)
# 17     NH    03110-6819  US      (42.94327, -71.4741)
# 18     MA    01845-5812  US      (42.665865, -71.115143)
# 19     MA    01810-3702  US      (42.656393, -71.140289)
# 20     NH    03301-6029  US      (43.222904, -71.491969)
# 21     NH    03063-3236  US      (42.76513, -71.49744)
# 22     MA    01915-1115  US      (42.585366, -70.88444)
# 23     MA    01854-5120  US      (42.641549, -71.334888)
# 24     NH    03060-5730  US      (42.700708, -71.436142)
# 25     NH    03063-1017  US      (42.80103, -71.537014)
# 26     MA    01852-5132  US      (42.62462, -71.31845)
# 27     MA    01915-2419  US      (42.556249, -70.890407)
sb_stores[['zipcode']] = sb_stores[['zipcode']].apply(
    lambda x: x.replace(
        to_replace='([0-9]{3,4})', 
        value=((5-len(x['zipcode']))*'0')+r'\1', 
        regex=True
    ), axis=1
)

# %%
tables = [
    ('sb_stores', sb_stores), 
    ('zipcodes', zip_counties),
    ('zip_data', zip_data),
    ('zip_data2', zip_data2),
    ('zip_data3', zip_data3)
]

for table, df in tables:
#     if table not in ['zipcodes', 'sb_stores']:
    df.replace({'-|': ''}, regex=True).apply(lambda x: pd.to_numeric(x, errors='ignore')).to_sql(table, engine, if_exists='replace', index=True)
#     else.
#         df.to_sql(table, engine, if_exists='replace', index=True)

# %%
df_left = pd.read_csv('/Users/tdobbins/Desktop/left_join.csv') # results from pgAdmin query
df_left['Street Address'] = df_left['Street Address'].fillna('NAN')
df_left['has_starbucks'] = [True if x != 'NAN' else False for x in df_left['Street Address']]

# %% [markdown]
# # exploration

# %%
# %%sql DB=econ MAKE_GLOBAL=df NOTIFY=3
# select *,
#     count(sb."zipcode") over (
#         partition by sb.zipcode
#     ) as num_of_sb,
# from zip_data z
# join zip_data2 z2 on z2."Id" = z."Id"
# join zip_data3 z3 on z3."Id" = z."Id"
# left join sb_stores sb on sb."zipcode" = z."Id2"
# Out:
#         <style>
#         .input {
#             position:relative;
#         }
#         #childDiv7a99213a-b94a-4c91-9259-4a52ae488826 {
#             width: 90%;
#             position:absolute;
#         }
#         #table7a99213a-b94a-4c91-9259-4a52ae488826{
#             padding-top: 40px;
#         }
#         </style>
#         <div class="row" id="childDiv7a99213a-b94a-4c91-9259-4a52ae488826">
#             <div class="btn-group col-md-3">
#                 <button id="explain" title="Explain Analyze Graph" onclick="explain('__EXPLAIN_GRAPH__')" type="button" class="btn btn-info btn-sm"><p class="fa fa-code-fork fa-rotate-270"</p></button>
#                 <button id="explain" title="Explain Analyze" onclick="explain('__EXPLAIN__')" type="button" class="btn btn-info btn-sm"><p class="fa fa-info-circle"</p></button>
#                 <button type="button" title="Execute" onclick="run()" class="btn btn-success btn-sm"><p class="fa fa-play"></p></button>
#                 <button type="button" title="Execute and Return Data as Variable" onclick="getData()" class="btn btn-success btn-sm"><p class="">var</p></button>
#                 <button id="saveData7a99213a-b94a-4c91-9259-4a52ae488826" title="Save" class="btn btn-success btn-sm disabled" type="button"><p class="fa fa-save"</p></button>
#                 <button id="cancelQuery7a99213a-b94a-4c91-9259-4a52ae488826" title="Cancel Query" class="btn btn-danger btn-sm" type="button"><p class="fa fa-stop"</p></button>
#             </div>
#             <div id="engineButtons7a99213a-b94a-4c91-9259-4a52ae488826" class="btn-group col-md-4"></div>
#             <div id="tableData7a99213a-b94a-4c91-9259-4a52ae488826"></div>
#         </div>
#         <div class="table" id="table7a99213a-b94a-4c91-9259-4a52ae488826"></div>
#         <script type="text/Javascript">
#
#             (function($) {
#                 var MutationObserver = window.MutationObserver || window.WebKitMutationObserver || window.MozMutationObserver;
#
#                 $.fn.attrchange = function(callback) {
#                     if (MutationObserver) {
#                         var options = {
#                             subtree: false,
#                             attributes: true
#                         };
#
#                         var observer = new MutationObserver(function(mutations) {
#                             mutations.forEach(function(e) {
#                                 callback.call(e.target, e.attributeName);
#                             });
#                         });
#
#                         return this.each(function() {
#                             observer.observe(this, options);
#                         });
#
#                     }
#                 }
#             } )(jQuery);
#             $("#childDiv7a99213a-b94a-4c91-9259-4a52ae488826").parents('.code_cell').attrchange(function(attrName){
#                 if (attrName=='class'){
#                     if ($(this).hasClass('unselected')){
#                         $("#childDiv7a99213a-b94a-4c91-9259-4a52ae488826").find('button').each(function(i, obj){
#                             $(obj).addClass('disabled');
#                         });
#                     } else if ($(this).hasClass('selected')){
#                         $("#childDiv7a99213a-b94a-4c91-9259-4a52ae488826").find('button').each(function(i, obj){
#                             $(obj).removeClass('disabled');
#                         });
#                     }
#                 }
#             });
#
#
#
#             var engines = JSON.parse(`{"PRODALL": {"engine": "postgresql://phdba:RXBpJd8fH7BTUDZdO8qB@phteam-prod.ccmhg5j69wvw.us-east-1.rds.amazonaws.com:5432/", "caution_level": "danger", "order": 3}, "DATALAKE": {"engine": "postgresql://tim.dobbins:2F5HVimo@db.phdatalake.perceptionhealth.com/", "caution_level": "danger", "order": 4}, "PROD": {"engine": "postgresql://phdba:RXBpJd8fH7BTUDZdO8qB@phteam-prod.ccmhg5j69wvw.us-east-1.rds.amazonaws.com:5432/", "caution_level": "danger", "order": 2}, "LOCAL": {"engine": "postgresql://phdba:RXBpJd8fH7BTUDZdO8qB@localhost:5432/", "caution_level": "warning", "order": 0}, "DEV": {"engine": "postgresql://phTeam:4zHam9MLDC@db.dev.phteam.perceptionhealth.com/", "caution_level": "warning", "order": 1}}`);
#
#             var sortedEngineKeys = Object.keys(engines).sort(function(a,b){
#                 return engines[a].order - engines[b].order;
#             });
#
#             var sortedEngines = sortedEngineKeys.reduce(function(output, row, idx){
#                 engines[row]['key'] = row;
#                 output.push(engines[row]);
#                 return output;
#             }, []);
#
#             var engineButtons = '';
#             for (var engine in sortedEngines){
#                 var engineKey = sortedEngines[engine].key;
#                 var warningLabel = sortedEngines[engine].caution_level;
#                 engineButtons += '<button title="Switch Engine" onclick="switchEngines('+"'"+engineKey+"'"+')" class="btn btn-'+warningLabel+' btn-sm">'+engineKey+'</button>';
#             };
#
#            $("#engineButtons7a99213a-b94a-4c91-9259-4a52ae488826").append(engineButtons);
#
#            $("#cancelQuery7a99213a-b94a-4c91-9259-4a52ae488826").on('click', function(){
#                if ($("#cancelQuery7a99213a-b94a-4c91-9259-4a52ae488826").hasClass('disabled')){
#                    console.log('alread stopped or finished query...');
#                } else {
#                    cancelQuery("c673bd18-a83c-4cd8-a7eb-c6a25a0dd9c3");
#                    //$("#cancelQuery7a99213a-b94a-4c91-9259-4a52ae488826").addClass('disabled')
#                }
#            });
#
#             function explain(gloVar){
#                 var command =  `__SQLCell_GLOBAL_VARS__.`+gloVar+` = True`;
#                 console.log(command);
#                 var kernel = IPython.notebook.kernel;
#                 kernel.execute(command);
#                 IPython.notebook.execute_cell();
#             };
#
#             function run(){
#                 IPython.notebook.execute_cell();
#                 $.get('/api/contents', function(data){
#                     console.log(data);
#                 });
#             };
#
#             function cancelQuery(applicationID){
#                 IPython.notebook.kernel.execute('__SQLCell_GLOBAL_VARS__().kill_last_pid_on_new_thread(__SQLCell_GLOBAL_VARS__.jupyter_id, "econ", "7a99213a-b94a-4c91-9259-4a52ae488826")',
#                     {
#                         iopub: {
#                             output: function(response) {
#                                 var $table = $("#table7a99213a-b94a-4c91-9259-4a52ae488826").parent();
#                                 console.log(response);
#                                 if (response.content && response.content.text){
#                                     $table.append('<h5 style="color:#d9534f;">'+response.content.text+'</h5>')
#                                 } else if (response.content && response.content.evalue){
#                                     $table.append('<h5 style="color:#d9534f;">'+response.content.evalue+'</h5>');
#                                 }
#                             }
#                         }
#                     },
#                     {
#                         silent: false,
#                         store_history: false,
#                         stop_on_error: true
#                     }
#                 );
#             };
#
#             function getData(){
#                 var command = `__SQLCell_GLOBAL_VARS__.__GETDATA__ = True`;
#                 var kernel = IPython.notebook.kernel;
#                 kernel.execute(command);
#                 IPython.notebook.execute_cell();
#             };
#
#             function saveData(data, filename){
#                 var path = $('#path').val() || './'
#                 var command = `__SQLCell_GLOBAL_VARS__.__SAVEDATA__, PATH = True,'`+path+`'`;
#                 var kernel = IPython.notebook.kernel;
#                 kernel.execute(command);
#                 //IPython.notebook.execut

# %%
# df_left = pd.read_csv('/Users/tdobbins/Desktop/left_join.csv') # results from SQL from ^^^ this cell
df['Street Address'] = df['Street Address'].fillna('NAN')
df['has_starbucks'] = [True if x != 'NAN' else False for x in df['Street Address']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-216-ac5ad1b746b0> in <module>()
#       1 # df_left = pd.read_csv('/Users/tdobbins/Desktop/left_join.csv') # results from SQL from ^^^ this cell
# ----> 2 df['Street Address'] = df['Street Address'].fillna('NAN')
#       3 df['has_starbucks'] = [True if x != 'NAN' else False for x in df['Street Address']]
#
# /usr/local/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1967             return self._getitem_multilevel(key)
#    1968         else:
# -> 1969             return self._getitem_column(key)
#    1970
#    1971     def _getitem_column(self, key):
#
# /usr/local/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1974         # get column
#    1975         if self.columns.is_unique:
# -> 1976             return self._get_item_cache(key)
#    1977
#    1978         # duplicate columns & possible reduce dimensionality
#
# /usr/local/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1089         res = cache.get(item)
#    1090         if res is None:
# -> 1091             values = self._data.get(item)
#    1092             res = self._box_item_values(item, values)
#    1093             cache[item] = res
#
# /usr/local/lib/python2.7/site-packages/pandas/core/internals.pyc in get(self, item, fastpath)
#    3209
#    3210             if not isnull(item):
# -> 3211                 loc = self.items.get_loc(item)
#    3212             else:
#    3213                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /usr/local/lib/python2.7/site-packages/pandas/core/index.pyc in get_loc(self, key, method, tolerance)
#    1757                                  'backfill or nearest lookups')
#    1758             key = _values_from_object(key)
# -> 1759             return self._engine.get_loc(key)
#    1760
#    1761         indexer = self.get_indexer([key], method=method,
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:3979)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:3843)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12265)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12216)()
#
# KeyError: 'Street Address'

# %%
# groupby has_starbucks to see why SB doesn't have a presence in certain zipcodes
df_group = df.groupby(['has_starbucks'])\
    .describe()\
    .unstack()
    
df_group
# Out:
#               Facility ID                                                  \
#                     count          mean          std   min     25%    50%
# has_starbucks
# False          0          NaN           NaN          NaN   NaN     NaN
# True           10700       14319.180748  10671.88966  6323  9531.5  12761
#
#                               Food Region                                     \
#                    75%    max       count        mean          std min   25%
# has_starbucks
# False         NaN      NaN     0          NaN         NaN          NaN NaN
# True           16052.5  89108  10700       9411.95729  2349.113489  0   9999
#
#                                 HC01_VC03                                  \
#                 50%   75%   max     count          mean           std min
# has_starbucks
# False         NaN   NaN   NaN    27880     5841.338702   9673.509357   0
# True           9999  9999  9999  10700     32481.886449  17514.146135  0
#
#                                                 HC01_VC103               \
#                  25%      50%       75%     max      count         mean
# has_starbucks
# False          562    1873.0   6420.25   115013  27880      1459.466571
# True           20394  30631.5  42335.00  113451  10700      7686.604673
#
#                                                            HC01_VC120  \
#                        std min   25%     50%    75%    max      count
# has_starbucks
# False          2306.254145  0   147   496.0   1670   24383  27880
# True           4292.327237  0   4653  7336.5  10276  27938  10700
#
#                                                                       \
#                       mean          std min   25%   50%   75%    max
# has_starbucks
# False          694.788307   1225.489211  0   64    210   702   18133
# True           4579.285794  3147.250767  0   2486  4053  5873  25998
#
#               HC01_VC21                                                     \
#                   count      mean       std   min   25%   50%   75%    max
# has_starbucks
# False          27253     2.558255  0.475931  1.01  2.30  2.52  2.75  14.50
# True           10607     2.554100  0.482727  1.06  2.29  2.54  2.82  4.89
#
#               HC01_VC22                                                     \
#                   count      mean       std   min   25%   50%   75%    max
# has_starbucks
# False          27206     3.067930  0.494108  1.31  2.82  3.03  3.26  12.00
# True           10606     3.155706  0.372911  1.80  2.95  3.13  3.34  5.04
#
#               HC01_VC23                                                     \
#                   count       mean       std   min   25%   50%   75%   max
# has_starbucks
# False          27396     42.437516  8.743724  5.9   37.3  42.1  47.2  91.8
# True           10662     37.561921  6.106708  18.8  33.9  37.4  41.1  74.5
#
#               HC01_VC88                                                  \
#                   count         mean          std min   25%   50%   75%
# has_starbucks
# False          27880     833.384792   3729.663152  0   2     40    274
# True           10700     6408.069159  9527.266312  0   1200  3044  7643
#
#                      HC03_VC04                                                \
#                  max     count       mean        std   min   25%   50%   75%
# has_starbucks
# False          93072  27593     59.432657  13.138088  0.0   53.5  61.0  67.3
# True           97775  10663     66.424683  8.103409   11.7  62.7  67.1  71.0
#
#                                                                              \
#                max  count       mean       std   min   25%   50%   75%  max
# has_starbucks
# False          100  27594  50.345137  7.129711  0.0   47.7  49.8  52.3  100
# True           100  10663  49.472072  3.632075  24.8  47.9  49.1  50.2  100
#
#                                                                        \
#                count       mean        std min   25%   50%   75%  max
# has_starbucks
# False          27370  68.841261  12.753968  0   63.4  69.6  75.7  100
# True           10608  62.142836  15.719856  0   55.1  65.2  73.1  100
#
#               HC03_VC05                                                    \
#                   count       mean       std min   25%   50%   75%    max
# has_starbucks
# False          27594     49.655030  7.129649  0   47.7  50.2  52.3  100.0
# True           10663     50.527938  3.632058  0   49.8  50.9  52.1  75.2
#
#                                                                        \
#                count       mean        std min   25%   50%   75%  max
# has_starbucks
# False          27370  26.347362  11.783364  0   20.6  26.4  32.0  100
# True           10608  28.125132  10.664401  0   22.3  28.4  34.4  100
#
#               HC03_VC06                                                     \
#                   count       mean        std min   25%   50%   75%    max
# has_starbucks
# False          27593     53.920570  13.594395  0   47.3  55.4  62.4  100.0
# True           10663     60.360555  9.101778   0   56.2  61.3  65.8  90.8
#
#                                                                        \
#                count       mean        std min   25%   50%   75%  max
# has_starbucks
# False          27370  53.511279  15.020295  0   46.2  54.4  62.0  100
# True           10608  47.037132  14.468737  0   38.3  48.5  57.4  100
#
#               HC03_VC07                                                       \
#                   count      mean       std min  25%  50%  75%    max  count
# has_starbucks
# False          27593     5.083626  4.369764  0   2.6  4.5  6.7  100.0  27370
# True           10663     5.381403  2.161415  0   4.0  5.1  6.4  39.1   10608
#
#                                                                HC03_VC08  \
#                     mean        std min   25%   50%   75%  max     count
# has_starbucks
# False          18.375016  10.372398  0   12.6  17.8  23.3  100  27593
# True           20.064480  9.313499   0   14.2  19.5  25.7  100  10663
#
#                                                                            \
#                    mean       std min 25%  50%  75%  max  count      mean
# has_starbucks
# False          0.428409  4.873747  0   0   0.0  0.0  100  27594  5.528503
# True           0.682903  5.166712  0   0   0.1  0.2  100  10663  5.874022
#
#                                                                              \
#                     std min  25%  50%  75%   max  count      mean       std
# has_starbucks
# False          3.545428  0   3.6  5.4  7.2  50.0  27370  4.727965  5.135273
# True           1.939140  0   4.8  5.9  7.0  19.7  10608  4.259408  2.580730
#
#                                       HC03_VC09                            \
#               min  25%  50%  75%  max     count       mean        std min
# has_starbucks
# False          0   2.0  4.1  6.1  100  27593     40.567575  13.138150  0
# True           0   2.9  4.0  5.3  100  10663     33.575317  8.103409   0
#
#                                                                             \
#                 25%   50%   75%    max  count      mean       std min  25%
# has_starbucks
# False          32.7  39.0  46.5  100.0  27594  5.951229  3.508110  0   4.1
# True           29.0  32.9  37.3  88.3   10663  5.887030  2.116629  0   4.9
#
#                                                                              \
#                50%  75%   max  count      mean       std min  25%  50%  75%
# has_starbucks
# False          6.0  7.6  68.8  27370  2.333467  3.680720  0   0.0  1.7  3.1
# True           6.1  7.2  24.1  10608  2.033890  1.541267  0   1.2  1.9  2.7
#
#                    HC03_VC10                                               \
#                max     count      mean       std min  25%  50%  75%   max
# has_starbucks
# False          100  27594     6.249504  3.563483  0   4.5  6.3  7.9  52.5
# True           100  10663     5.892244  2.259041  0   4.7  6.1  7.4  25.3
#
#                                                                        \
#                count       mean       std min  25%   50%     75%  max
# has_starbucks
# False          27370  10.602368  8.588956  0   5.5  9.2   13.775  100
# True           10608  10.844702  5.051682  0   7.6  10.3  13.500  100
#
#               HC03_VC101                                                  \
#                    count       mean        std min  25%   50%   75%  max
# has_starbucks
# False          27370      13.220570  11.129404  0   5.5  11.1  18.2  100
# True           10608      9.237575   7.769557   0   3.6  7.1   12.8  100
#
#                                                                    HC03_VC104  \
#                count       mean       std min  25%  50%   75%  max      count
# has_starbucks
# False          27576  10.551425  6.630699  0   7.4  9.9  12.6  100  27206
# True           10661  8.210618   4.440387  0   5.7  7.8  9.9   100  10606
#
#                                                             HC03_VC105  \
#                    mean       std min  25%  50%  75%    max      count
# has_starbucks
# False          4.779784  6.546613  0   0.7  3.1  6.4  100.0  27206
# True           4.001188  3.550712  0   1.8  3.1  5.2  54.4   10606
#
#                                                           HC03_VC106  \
#                    mean       std min  25%  50%  75%  max      count
# has_starbucks
# False          3.423355  5.076327  0   0.0  2.2  4.7  100  27206
# True           2.558439  2.398635  0   1.1  2.0  3.5  100  10606
#
#                                                                               \
#                    mean       std min  25%  50%   75%  max  count       mean
# has_starbucks
# False          9.338569  8.952485  0   4.0  7.9  12.5  100  27508  15.868442
# True           6.401037  4.555471  0   3.2  5.3  8.7   50   10653  10.413780
#
#                                                      HC03_VC107             \
#                     std min   25%   50%   75%    max      count       mean
# has_starbucks
# False          8.988855  0   10.8  14.6  19.1  100.0  27206      10.644332
# True           4.138972  0   7.8   9.8   12.4  64.1   10606      7.233490
#
#                                                  HC03_VC108             \
#                     std min  25%  50%   75%  max      count       mean
# has_starbucks
# False          8.619182  0   5.8  9.7  13.7  100  27206      15.167603
# True           4.052203  0   4.3  6.8  9.6   100  10606      10.853705
#
#                                                    HC03_VC109             \
#                     std min   25%   50%   75%  max      count       mean
# has_starbucks
# False          9.908692  0   10.2  14.5  18.6  100  27206      21.353150
# True           4.991885  0   7.4   10.8  14.1  100  10606      16.629983
#
#                                                                         \
#                      std min   25%   50%   75%    max  count      mean
# has_starbucks
# False          11.071153  0   16.0  20.9  25.6  100.0  26575  4.771484
# True           5.400823   0   13.2  17.1  20.3  55.6   10622  3.375325
#
#                                                 HC03_VC11                      \
#                     std min  25%  50%  75%  max     count      mean       std
# has_starbucks
# False          6.958801  0   0.8  3.4  6.3  100  27594     6.598742  5.642787
# True           2.462639  0   2.1  3.0  4.2  100  10663     6.685961  5.066193
#
#                                                                              \
#               min  25%  50%  75%    max  count      mean       std min  25%
# has_starbucks
# False          0   4.5  6.2  7.8  100.0  27370  5.639492  5.801579  0   2.0
# True           0   5.0  6.3  7.4  85.5   10608  6.026037  3.338784  0   3.8
#
#                              HC03_VC110                                       \
#                50%  75%  max      count       mean       std min   25%   50%
# has_starbucks
# False          4.7  7.7  100  27206      14.395696  9.327529  0   9.5   14.0
# True           5.6  7.7  100  10606      13.583472  4.191046  0   11.2  13.8
#
#                          HC03_VC111                                            \
#                 75%  max      count       mean      std min   25%   50%   75%
# has_starbucks
# False          18.3  100  27206      13.321425  9.80053  0   7.0   12.1  18.2
# True           16.2  100  10606      18.234801  6.25644  0   14.1  18.6  22.6
#
#                    HC03_VC112                                               \
#                max      count      mean       std min  25%  50%   75%  max
# has_starbucks
# False          100  27206      4.052143  5.833478  0   0.0  2.5  5.5   100
# True           100  10606      8.851028  5.242520  0   4.7  8.4  12.5  100
#
#                                                                      \
#                count       mean       std min  25%   50%   75%  max
# has_starbucks
# False          27415  13.546256  9.530272  0   8.0  12.0  17.0  100
# True           10653  8.113536   4.281940  0   5.3  7.3   10.1  100
#
#               HC03_VC113                                                 \
#                    count       mean        std min  25%  50%   75%  max
# has_starbucks
# False          27206      3.525017   6.819703   0   0.0  1.5  4.0   100
# True           10606      11.651829  11.497846  0   3.4  7.6  16.1  100
#
#               HC03_VC115                                                   \
#                    count       mean        std min   25%   50%   75%  max
# has_starbucks
# False          26879      38.451959  16.242560  0   29.6  37.4  46.1  100
# True           10588      33.998546  8.616488   0   29.1  33.9  38.9  100
#
#               HC03_VC12                                                        \
#                   count      mean       std min  25%  50%   75%    max  count
# has_starbucks
# False          27384     8.929671  7.930215  0   4.4  7.6  11.5  100.0  27594
# True           10660     8.395722  4.085229  0   5.9  7.7  10.0  93.8   10663
#
#                                                                              \
#                    mean       std min  25%  50%  75%  max  count       mean
# has_starbucks
# False          5.857020  5.636491  0   3.4  5.2  7.0  100  27370  31.159065
# True           7.787799  5.480592  0   5.2  6.5  8.3  83   10608  37.857164
#
#                                                     HC03_VC120             \
#                      std min   25%   50%   75%  max      count       mean
# has_starbucks
# False          12.754089  0   24.3  30.4  36.6  100  27594      88.499743
# True           15.719856  0   26.9  34.8  44.9  100  10663      81.593220
#
#                                                    HC03_VC121             \
#                     std min   25%   50%   75%  max      count       mean
# has_starbucks
# False          9.723929  0   85.3  89.9  93.9  100  27594      11.223599
# True           9.271723  0   78.6  83.5  87.3  100  10663      17.422179
#
#                                                    HC03_VC122             \
#                     std min   25%   50%   75%  max      count       mean
# has_starbucks
# False          9.491120  0   5.9   9.8   14.4  100  27594      5.944745
# True           8.747613  0   12.0  15.7  20.4  100  10663      10.496549
#
#                                                    HC03_VC123            \
#                     std min  25%  50%   75%    max      count      mean
# has_starbucks
# False          6.046005  0   2.1  4.9  8.2   100.0  27594      5.278948
# True           5.239754  0   7.0  9.7  13.0  76.1   10663      6.927422
#
#                                                   HC03_VC124            \
#                     std min  25%  50%  75%    max      count      mean
# has_starbucks
# False          7.063952  0   1.8  3.8  6.5  100.0  27594      3.311629
# True           5.864828  0   3.8  5.7  8.2  88.2   10663      3.573347
#
#                                                 HC03_VC125            \
#                     std min  25%  50%  75%  max      count      mean
# has_starbucks
# False          5.097733  0   0.6  2.2  4.2  100  27594      1.967511
# True           3.713300  0   1.7  2.9  4.4  63   10663      3.355125
#
#                                                   HC03_VC126            \
#                     std min  25%  50%  75%    max      count      mean
# has_starbucks
# False          4.458827  0   0.0  0.9  2.2  100.0  27594      0.277162
# True           3.951492  0   1.4  2.5  4.1  86.5   10663      0.984413
#
#                                                 HC03_VC13             \
#                    std min  25%  50%  75%   max     count       mean
# has_starbucks
# False          0.99297  0   0.0  0.0  0.2  50.0  27594     10.783319
# True           1.21323  0   0.3  0.6  1.2  26.7  10663     15.381347
#
#                                                                         \
#                     std min   25%   50%   75%    max  count       mean
# has_starbucks
# False          5.956236  0   7.9   10.6  13.3  100.0  27370  26.389583
# True           6.597762  0   11.6  14.1  17.1  52.8   10608  30.129506
#
#                                                     HC03_VC131             \
#                      std min   25%   50%   75%  max      count       mean
# has_starbucks
# False          11.747180  0   20.0  25.8  31.5  100  27508      86.233754
# True           12.432818  0   21.7  28.1  35.5  100  10653      87.517094
#
#                                                                       \
#                     std min   25%   50%   75%  max  count       mean
# has_starbucks
# False          9.719289  0   82.0  87.9  92.6  100  27594  95.695126
# True           6.977837  37  83.7  88.8  92.5  100  10663  83.669099
#
#                                                       HC03_VC132             \
#                      std   min   25%   50%   75%  max      count       mean
# has_starbucks
# False          7.640747   0.0   95.3  98.4  99.8  100  27508      64.761706
# True           11.578895  26.2  77.7  86.7  92.6  100  10653      71.725983
#
#                                                                          \
#                      std min     25%   50%   75%  max  count       mean
# has_starbucks
# False          17.432076  0   54.675  66.7  77.0  100  27594  94.927941
# True           14.369501  0   63.500  74.4  82.6  100  10663  82.139670
#
#                                                       HC03_VC133             \
#                      std   min   25%   50%   75%  max      count       mean
# has_starbucks
# False          8.220676   0.0   94.3  97.8  99.4  100  27508      35.910648
# True           11.840619  23.2  75.8  85.1  91.2  100  10653      26.175359
#
#                                                                          \
#                      std min   25%   50%   75%    max  count       mean
# has_starbucks
# False          13.711284  0   27.5  35.1  43.1  100.0  27594  69.038313
# True           9.745403   0   19.7  25.1  31.7  93.6   10663  49.973994
#
#                                                     HC03_VC134             \
#                      std min   25%   50%   75%  max      count       mean
# has_starbucks
# False          18.597955  0   59.0  73.2  82.6  100  27508      13.766464
# True           16.045191  0   38.8  50.4  61.4  100  10653      12.482925
#
#                                                                      \
#                     std min  25%   50%   75%  max  count       mean
# has_starbucks
# False          9.719341  0   7.4  12.1  18.0  100  27594  25.889813
# True           6.977821  0   7.5  11.2  16.3  63   10663  32.165544
#
#                                                     HC03_VC135            \
#                      std min   25%   50%   75%  max      count      mean
# has_starbucks
# False          17.015351  0   14.0  21.7  33.6  100  27594      0.767330
# True           15.661745  0   20.2  30.4  42.9  100  10663      1.528463
#
#                                                   HC03_VC136             \
#                     std min  25%  50%  75%    max      count       mean
# has_starbucks
# False          1.898484  0   0.0  0.3  0.9  100.0  27594      4.304943
# True           1.181590  0   0.9  1.3  1.8  25.2   10663      16.330901
#
#                                                      HC03_VC138            \
#                      std min  25%   50%   75%    max      count      mean
# has_starbucks
# False          7.640783   0   0.2  1.6   4.7   100.0  26575      7.482427
# True           11.578895  0   7.4  13.3  22.3  73.8   10622      6.292629
#
#                                                  HC03_VC14             \
#                      std min  25%  50%  75%  max     count       mean
# has_starbucks
# False          11.147891  0   0.2  4.2  9.7  100  27594     11.583870
# True           5.151346   0   2.9  5.2  8.4  100  10663     13.367167
#
#                                                                         \
#                     std min   25%   50%   75%    max  count       mean
# has_starbucks
# False          5.424167  0   9.3   11.7  13.8  100.0  27370  11.222989
# True           2.890294  0   11.8  13.3  15.0  29.3   10608  9.477545
#
#                                                     HC03_VC141             \
#                     std min  25%   50%   75%    max      count       mean
# has_starbucks
# False          7.840983  0   7.1  10.5  14.1  100.0  21524      50.285398
# True           4.292097  0   6.6  9.2   11.9  81.1   10644      48.625329
#
#                                                     HC03_VC142             \
#                      std min   25%   50%   75%  max      count       mean
# has_starbucks
# False          31.925637  0   25.0  50.0  74.2  100  21524      49.715341
# True           15.068507  0   38.5  49.4  59.3  100  10644      51.374775
#
#                                                     HC03_VC144             \
#                      std min   25%   50%   75%  max      count       mean
# has_starbucks
# False          31.925693  0   25.8  50.0  75.0  100  27281      82.428206
# True           15.068490  0   40.7  50.6  61.5  100  10652      85.136153
#
#                                                     HC03_VC145             \
#                      std min   25%   50%   75%  max      count       mean
# has_starbucks
# False          13.639434  0   76.7  85.1  91.3  100  27281      77.090928
# True           9.121038   0   80.4  87.1  91.7  100  10652      81.074446
#
#                                                     HC03_VC146            \
#                      std min   25%   50%   75%  max      count      mean
# has_starbucks
# False          15.488464  0   70.2  79.7  87.3  100  27281      7.723053
# True           11.347241  0   75.3  83.5  89.2  100  10652      5.822146
#
#                                                    HC03_VC147             \
#                     std min  25%  50%   75%    max      count       mean
# has_starbucks
# False          8.101458  0   3.2  6.2  10.0  100.0  27281      17.572094
# True           4.602301  0   3.1  4.9  7.4   92.8   10652      14.863950
#
#                                                   HC03_VC149             \
#                     std min  25%   50%   75%  max      count       mean
# has_starbucks
# False          13.63956  0   8.7  14.9  23.3  100  24603      55.769361
# True           9.12103   0   8.3  12.9  19.6  100  10633      61.741973
#
#                                                     HC03_VC15             \
#                      std min   25%   50%   75%  max     count       mean
# has_starbucks
# False          27.624838  0   38.2  56.6  75.0  100  27495     54.690020
# True           15.280379  0   51.5  61.5  72.2  100  10662     60.881214
#
#                                                                        \
#                      std min   25%   50%   75%  max  count       mean
# has_starbucks
# False          14.104510  0   48.1  55.8  62.7  100  27594  14.946804
# True           8.062528   0   56.5  61.0  65.4  100  10663  13.806302
#
#                                                      HC03_VC150             \
#                     std min   25%   50%   75%    max      count       mean
# has_starbucks
# False          6.583973  0   12.3  14.6  17.2  100.0  24603      36.359854
# True           3.023161  0   12.3  14.0  15.6  74.2   10633      45.991395
#
#                                                     HC03_VC151             \
#                      std min   25%   50%   75%  max      count       mean
# has_starbucks
# False          27.400519  0   15.8  32.6  52.6  100  24603      21.990022
# True           18.497067  0   31.8  45.1  59.3  100  10633      18.146826
#
#                                                     HC03_VC152             \
#                      std min   25%   50%   75%  max      count       mean
# has_starbucks
# False          21.809628  0   3.4   17.9  32.3  100  24603      44.231431
# True           11.585678  0   10.4  16.2  24.1  100  10633      38.258140
#
#                                                     HC03_VC154             \
#                      std min   25%   50%   75%  max      count       mean
# has_starbucks
# False          27.624861  0   25.0  43.4  61.8  100  26941      79.839427
# True           15.280404  0   27.8  38.5  48.5  100  10649      82.135468
#
#                                                     HC03_VC155             \
#                      std min   25%   50%   75%  max      count       mean
# has_starbucks
# False          16.114917  0   72.3  82.4  90.9  100  26941      50.322026
# True           9.818254   0   76.7  83.6  89.3  100  10649      60.994854
#
#                                                   HC03_VC156             \
#                      std min   25%   50% 75%  max      count       mean
# has_starbucks
# False          22.982340  0   34.8  49.4  66  100  26941      37.706421
# True           18.727662  0   47.7  62.9  76  100  10649      26.881980
#
#                                                     HC03_VC157             \
#                      std min   25%   50%   75%  max      count       mean
# has_starbucks
# False          19.603843  0   25.0  37.5  49.4  100  26941      20.161082
# True           13.929508  0   16.6  25.5  35.8  100  10649      17.864569
#
#                                                     HC03_VC16            \
#                      std min   25%   50%   75%  max     count      mean
# has_starbucks
# False          16.115041  0   9.1   17.6  27.7  100  27594     7.762430
# True           9.818251   0   10.7  16.4  23.3  100  10663     6.388587
#
#                                                   HC03_VC161             \
#                     std min  25%  50%  75%    max      count       mean
# has_starbucks
# False          5.107660  0   5.6  7.2  9.0  100.0  27206      11.608414
# True           1.810299  0   5.5  6.4  7.3  76.1   10606      9.346672
#
#                                                   HC03_VC162             \
#                      std min  25%  50%   75%  max      count       mean
# has_starbucks
# False          11.099384  0   4.3  9.1  15.7  100  26447      18.925371
# True           7.485280   0   4.2  7.2  12.2  100  10580      14.501333
#
#                                                    HC03_VC163             \
#                      std min  25%   50%   75%  max      count       mean
# has_starbucks
# False          17.408593  0   6.4  15.4  26.7  100  23169      20.431201
# True           11.561157  0   6.1  11.3  20.3  100  10547      14.205035
#
#                                                    HC03_VC164            \
#                      std min  25%   50%   75%  max      count      mean
# has_starbucks
# False          24.744864  0   0.0  12.5  32.0  100  27086      6.668079
# True           14.068369  0   3.8  10.4  20.9  100  10601      5.122205
#
#                                                   HC03_VC165            \
#                     std min  25%  50%  75%    max      count      mean
# has_starbucks
# False          8.737811  0   1.4  4.4  8.7  100.0  25981      9.947866
# True           4.816809  0   2.2  3.7  6.5  63.2   10552      7.353563
#
#                                                   HC03_VC166            \
#                      std min  25%  50%   75%  max      count      mean
# has_starbucks
# False          13.961981  0   0.0  5.7  13.5  100  21890      8.771265
# True           7.762983   0   2.3  4.8  9.7   100  10516      6.020226
#
#                                                 HC03_VC167             \
#                      std min 25%  50%  75%  max      count       mean
# has_starbucks
# False          18.914797  0   0   0.0  9.3  100  24830      31.106738
# True           9.295373   0   0   2.9  8.3  100  10565      23.543947
#
#                                                     HC03_VC168             \
#                      std min   25%   50%   75%  max      count       mean
# has_starbucks
# False          24.067459  0   12.6  29.3  44.6  100  23468      41.586539
# True           13.553683  0   13.8  21.9  31.0  100  10494      31.165447
#
#                                                     HC03_VC169             \
#                      std min   25%   50%   75%  max      count       mean
# has_starbucks
# False          28.646672  0   20.0  40.9  59.8  100  15852      49.504933
# True           16.533967  0   19.2  30.0  42.1  100  9958       36.196154
#
#                                                     HC03_VC17             \
#                      std min   25%   50%   75%  max     count       mean
# has_starbucks
# False          38.730874  0   0.0   50.0  90.5  100  27495     50.084404
# True           27.420577  0   12.9  35.3  55.1  100  10662     55.742037
#
#                                                                        \
#                      std min    25%   50%   75%  max  count      mean
# has_starbucks
# False          14.353789  0   42.95  51.0  58.4  100  27594  7.084087
# True           8.600250   0   51.30  56.1  60.6  100  10663  5.597899
#
#                                                                      \
#                     std min  25%  50%  75%    max  count       mean
# has_starbucks
# False          5.263045  0   4.8  6.4  8.3  100.0  27370  29.932638
# True           1.723834  0   4.6  5.5  6.5  47.2   10608  30.718533
#
#                                                     HC03_VC171             \
#                      std min   25%   50%   75%  max      count       mean
# has_starbucks
# False          12.547578  0   23.8  30.0  35.9  100  27426      15.710176
# True           11.566660  0   24.4  31.2  37.7  100  10621      13.481273
#
#                                                                       \
#                      std min  25%   50%   75%  max  count       mean
# has_starbucks
# False          12.362226  0   7.5  13.2  20.8  100  27594  91.213912
# True           9.501987   0   7.0  11.0  17.6  100  10663  76.299109
#
#                                                      HC03_VC172             \
#                      std  min   25%   50%   75%  max      count       mean
# has_starbucks
# False          14.539793  0.0  91.0  96.5  98.8  100  26463      21.601168
# True           17.055040  3.1  68.3  80.9  89.2  100  10581      17.083839
#
#                                                                       \
#                      std min  25%   50%   75%  max  count       mean
# has_starbucks
# False          19.286522  0   7.0  17.7  31.1  100  27594  8.786196
# True           13.496177  0   7.1  13.3  24.3  100  10663  23.700910
#
#                                                         HC03_VC173             \
#                      std min     25%   50%   75%    max      count       mean
# has_starbucks
# False          14.539818  0   1.225   3.5   9.0   100.0  26447      21.124835
# True           17.055021  0   10.800  19.1  31.7  96.9   10580      16.710567
#
#                                                    HC03_VC174             \
#                      std min  25%   50%   75%  max      count       mean
# has_starbucks
# False          19.212053  0   6.5  17.1  30.6  100  24901      24.259889
# True           13.460335  0   6.7  12.8  23.8  100  10557      18.170749
#
#                                                    HC03_VC175             \
#                      std min  25%   50%   75%  max      count       mean
# has_starbucks
# False          23.784411  0   3.5  19.0  37.2  100  26243      20.001250
# True           15.346274  0   6.4  14.2  26.8  100  10547      16.160339
#
#                                                    HC03_VC176             \
#                      std min  25%   50%   75%  max      count       mean
# has_starbucks
# False          19.163348  0   5.4  15.7  29.0  100  27425      13.915092
# True           13.262982  0   6.4  12.2  22.5  100  10621      12.349525
#
#                                                    HC03_VC177             \
#                      std min  25%   50%   75%  max      count       mean
# has_starbucks
# False          11.063985  0   7.0  11.7  18.0  100  27331      15.006191
# True           8.887859   0   6.5  10.1  15.5  100  10621      12.988250
#
#                                                    HC03_VC178             \
#                      std min  25%   50%   75%  max      count       mean
# has_starbucks
# False          12.402681  0   7.1  12.5  19.7  100  26879      10.090509
# True           9.397308   0   6.7  10.7  16.6  100  10587      9.046614
#
#                                                   HC03_VC179             \
#                      std min  25%  50%   75%  max      count       mean
# has_starbucks
# False          10.964750  0   3.5  7.8  13.3  100  27206      12.878722
# True           7.568162   0   4.8  7.1  10.6  100  10606      10.252866
#
#                                                    HC03_VC18             \
#                      std min  25%   50%   75%  max     count       mean
# has_starbucks
# False          12.246377  0   4.4  10.1  17.8  100  27594     10.133058
# True           8.334859   0   4.4  7.9   13.9  100  10663     7.310691
#
#                                                                      \
#                     std min  25% 50%   75%    max  count       mean
# has_starbucks
# False          7.289320  0   6.7  9   11.8  100.0  27370  30.623657
# True           2.916247  0   5.6  7   8.5   49.6   10608  24.114093
#
#                                                       HC03_VC180             \
#                      std min     25%   50%   75%  max      count       mean
# has_starbucks
# False          12.679502  0   24.025  29.5  35.3  100  26968      27.621818
# True           8.476608   0   18.900  23.6  28.6  100  10614      22.843273
#
#                                                     HC03_VC19            \
#                      std min   25%   50%   75%  max     count      mean
# has_starbucks
# False          16.641897  0   17.3  25.8  35.6  100  27594     5.483322
# True           10.759953  0   15.4  20.6  27.4  100  10663     4.096689
#
#                                                   HC03_VC20             \
#                     std min  25%  50%  75%    max     count       mean
# has_starbucks
# False          5.111002  0   3.2  4.8  6.6  100.0  25117     64.594553
# True           2.273191  0   2.7  3.8  5.0  52.8   10560     64.432812
#
#                                                                       \
#                      std min   25%   50%   75%  max  count      mean
# has_starbucks
# False          24.341508  0   52.2  67.5  80.7  100  27594  2.038584
# True           10.985210  0   58.6  64.9  71.0  100  10663  1.924552
#
#                                                  HC03_VC23             \
#                     std min  25%  50%  75%   max     count       mean
# has_starbucks
# False          2.855216  0   0.7  1.6  2.6  96.4  26113     70.090426
# True           1.260652  0   1.1  1.7  2.5  21.3  10547     70.722689
#
#                                                     HC03_VC26             \
#                      std min   25%   50%   75%  max     count       mean
# has_starbucks
# False          20.391886  0   61.4  72.7  82.7  100  27594     78.321936
# True           9.736765   0   66.0  71.4  76.4  100  10663     78.748729
#
#                                                      HC03_VC27             \
#                     std   min   25%   50%   75%  max     count       mean
# has_starbucks
# False          8.201185  0.0   73.9  77.7  81.8  100  27594     74.362206
# True           6.687450  50.6  74.6  77.7  81.5  100  10663     74.031858
#
#                                                                        \
#                     std  min   25%   50%   75%  max  count       mean
# has_starbucks
# False          9.589989  0.0  69.9  74.0  78.3  100  27370  40.545360
# True           7.960611  2.3  70.2  73.5  77.1  100  10608  40.689329
#
#                                                      HC03_VC28             \
#                     std   min   25%   50%   75%  max     count       mean
# has_starbucks
# False          8.099732  6.9   36.4  39.7  43.5  100  27378     77.931423
# True           8.581664  20.5  35.5  39.3  43.7  100  10663     72.420951
#
#                                                                        \
#                      std min   25%   50%   75%  max  count       mean
# has_starbucks
# False          14.858097  0   74.0  80.9  85.9  100  27594  21.778278
# True           17.492421  0   70.8  78.3  82.3  100  10663  16.577652
#
#                                                                                \
#                      std min   25% 50%   75%  max  count       mean       std
# has_starbucks
# False          11.672197  0   15.7  20  25.3  100  27370  21.261282  6.244248
# True           6.612955   0   12.6  16  19.6  100  10608  18.255307  4.412791
#
#                                           HC03_VC29                           \
#               min   25%   50%   75%   max     count       mean       std min
# has_starbucks
# False          0   18.4  21.7  24.4  69.2  27378     10.055347  8.126570  0
# True           0   15.3  18.9  21.5  50.0  10663     8.710138   3.685749  0
#
#                                                                              \
#                25%  50%   75%    max  count       mean        std min   25%
# has_starbucks
# False          5.9  9.1  12.7  100.0  27594  17.655179  10.450317  0   12.3
# True           6.4  8.4  10.7  40.4   10663  13.331436  5.822496   0   9.8
#
#                                                                               \
#                 50%   75%    max  count       mean       std min   25%   50%
# has_starbucks
# False          16.1  20.6  100.0  27370  27.729266  8.689786  0   24.0  28.6
# True           12.8  15.9  79.1   10608  27.764282  7.915971  0   24.5  29.3
#
#                           HC03_VC30                                          \
#                 75%   max     count      mean        std min  25%  50%  75%
# has_starbucks
# False          32.5  78.8  27378     1.373417  5.202159   0   0.0  0.0  0.7
# True           32.9  59.1  10663     6.253784  10.755355  0   0.8  2.3  6.5
#
#                                                                         \
#                max  count      mean       std min  25%  50%  75%   max
# has_starbucks
# False          100  27370  5.809364  5.172112  0   2.4  4.8  7.8  82.6
# True           100  10608  6.056721  3.585371  0   3.5  5.3  7.7  52.8
#
#               HC03_VC31                                                     \
#                   count      mean       std min  25%  50%  75%  max  count
# has_starbucks
# False          27378     3.512404  7.696938  0   0.1  1.5  3.6  100  27370
# ...
# False          2.996449  10.75999  0   0.0  0.6  1.7  100.0  26773  23.893938
# True           1.537766  1.95775   0   0.6  1.1  1.9  67.7   10659  18.736401
#
#                                                       HC03_VC81             \
#                      std min   25%   50%   75%    max     count       mean
# has_starbucks
# False          13.293521  0   18.0  23.0  28.3  100.0  27370     11.856606
# True           6.277443   0   16.1  20.2  22.8  62.1   10608     12.419891
#
#                                                                        \
#                     std min   25%   50%   75%    max  count      mean
# has_starbucks
# False          7.718220  0   7.8   11.5  15.1  100.0  27594  1.494963
# True           3.206357  0   10.4  12.5  14.5  62.1   10663  9.852321
#
#                                                                       \
#                      std min  25%  50%   75%    max  count      mean
# has_starbucks
# False          4.387350   0   0.0  0.3  1.3   100.0  26773  20.63836
# True           10.748609  0   3.1  6.4  12.6  76.8   10659  34.29439
#
#                                                     HC03_VC82             \
#                      std min   25%   50%   75%  max     count       mean
# has_starbucks
# False          15.960031  0   12.1  18.3  25.1  100  27370     10.595269
# True           18.101485  0   22.9  28.5  38.0  100  10608     15.208305
#
#                                                                                \
#                     std min   25%   50%   75%  max  count      mean       std
# has_starbucks
# False          8.015520  0   5.4   9.4   14.4  100  27594  0.196148  1.852181
# True           5.763016  0   11.1  15.4  19.2  100  10663  0.606424  2.147423
#
#                                        HC03_VC83                               \
#               min  25%  50%  75%   max     count      mean       std min  25%
# has_starbucks
# False          0   0.0  0.0  0.0  85.5  27370     3.208816  4.720031  0   0.2
# True           0   0.1  0.2  0.6  65.7  10608     6.892176  4.090681  0   3.5
#
#                                                                                \
#                50%  75%    max  count      mean       std min  25%  50%   75%
# has_starbucks
# False          2.0  4.2  100.0  27594  1.996970  5.375298  0   0.0  0.2  1.50
# True           6.3  9.7  24.1   10663  5.141686  6.585302  0   1.3  2.8  6.25
#
#                      HC03_VC84                                               \
#                  max     count      mean       std min  25%  50%   75%  max
# has_starbucks
# False          100.0  27370     2.812769  5.614361  0   0.0  1.2  3.1   100
# True           61.7   10608     8.358946  8.185952  0   2.5  5.7  11.3  100
#
#               HC03_VC86                                                \
#                   count      mean       std min  25%  50%  75%    max
# has_starbucks
# False          27559     5.464019  6.534227  0   1.7  3.7  7.0  100.0
# True           10656     4.529045  4.976279  0   1.6  2.9  5.4  52.2
#
#               HC03_VC87                                                 \
#                   count      mean       std min  25%  50%   75%    max
# has_starbucks
# False          27559     8.965957  7.004251  0   4.5  7.8  12.1  100.0
# True           10656     5.672354  4.079756  0   2.7  4.8  7.5   47.6
#
#               HC03_VC88                                                   \
#                   count       mean        std min   25%   50%   75%  max
# has_starbucks
# False          27559     36.189833  12.510397  0   29.4  36.5  43.3  100
# True           10656     20.849653  8.876937   0   14.5  21.0  27.0  100
#
#               HC03_VC89                                                   \
#                   count       mean        std min   25%   50%   75%  max
# has_starbucks
# False          27370     73.529112  13.250184  0   67.7  75.1  81.4  100
# True           10608     80.611812  7.574859   18  76.9  81.3  85.5  100
#
#                                                                       \
#                count       mean       std min   25%   50%   75%  max
# has_starbucks
# False          27559  21.401720  9.009291  0   16.8  21.0  25.3  100
# True           10656  20.680011  6.466388  0   16.7  21.1  24.8  100
#
#               HC03_VC90                                               \
#                   count      mean       std min  25%  50%   75%  max
# has_starbucks
# False          27559     8.281433  5.599816  0   5.2  7.8  10.6  100
# True           10656     7.571181  2.977547  0   5.9  7.6  9.3   100
#
#               HC03_VC91                                                   \
#                   count       mean        std min   25%   50%   75%  max
# has_starbucks
# False          27370     36.158151  13.644418  0   28.7  35.2  42.1  100
# True           10608     25.563650  8.754831   0   20.1  25.2  30.4  100
#
#                                                                         \
#                count       mean       std min   25%   50%     75%  max
# has_starbucks
# False          27559  12.844036  9.200518  0   7.2   11.1  16.600  100
# True           10656  24.374794  9.627727  0   16.9  24.1  31.325  100
#
#               HC03_VC92                                                  \
#                   count       mean        std min  25%   50%   75%  max
# has_starbucks
# False          27559     6.853761   7.619612   0   2.6  4.9   8.4   100
# True           10656     16.322682  10.579389  0   8.3  14.0  21.7  100
#
#               HC03_VC93                                                   \
#                   count       mean        std min   25%   50%   75%  max
# has_starbucks
# False          27370     20.226423  10.971382  0   14.1  19.3  24.8  100
# True           10608     16.147888  6.326250   0   12.0  16.0  20.0  100
#
#               HC03_VC95                                                      \
#                   count       mean        std   min   25%   50%    75%  max
# has_starbucks
# False          27559     85.570576  10.766603  0.0   80.7  87.8  92.75  100
# True           10656     89.798545  8.340559   31.6  87.0  92.1  95.40  100
#
#               HC03_VC96                                                   \
#                   count       mean        std min   25%   50%   75%  max
# has_starbucks
# False          27559     19.697518  14.267319  0   10.9  16.4  24.6  100
# True           10656     40.696528  18.874452  0   25.8  38.6  53.8  100
#
#               HC03_VC97                                                \
#                   count      mean       std min  25%  50%  75%    max
# has_starbucks
# False          27370     5.834034  6.247825  0   2.3  4.6  7.6  100.0
# True           10608     4.170994  2.978372  0   2.2  3.5  5.2  55.7
#
#               HC03_VC99                                                  Id2  \
#                   count      mean       std min  25%  50%  75%    max  count
# has_starbucks
# False          27370     2.560709  3.873043  0   0.2  1.7  3.4  100.0  27880
# True           10608     2.471719  2.193717  0   1.1  1.9  3.1  34.6   10700
#
#                                                                              \
#                        mean           std   min      25%      50%       75%
# has_starbucks
# False          48550.747346  26448.969127  1001  26373.5  49241.5  68846.25
# True           62466.455234  31526.505647  1002  32821.0  75087.0  92136.25
#
#                                                                         \
#                  max  count          mean           std   min      25%
# has_starbucks
# False          99929  27880  48550.747346  26448.969127  1001  26373.5
# True           99901  10700  62466.455234  31526.505647  1002  32821.0
#
#                                                                             \
#                    50%       75%    max  count          mean           std
# has_starbucks
# False          49241.5  68846.25  99929  27880  48550.747346  26448.969127
# True           75087.0  92136.25  99901  10700  62466.455234  31526.505647
#
#                                                        Latitude            \
#                 min      25%      50%       75%    max    count      mean
# has_starbucks
# False          1001  26373.5  49241.5  68846.25  99929  0       NaN
# True           1002  32821.0  75087.0  92136.25  99901  10700    37.79342
#
#                                                                      \
#                     std        min        25%        50%        75%
# has_starbucks
# False         NaN       NaN        NaN        NaN        NaN
# True           5.454977  19.645157  33.877509  38.322845  41.254656
#
#                          Longitude                                    \
#                      max     count       mean        std         min
# has_starbucks
# False         NaN         0        NaN        NaN        NaN
# True           64.853857  10700    -99.123692  18.977885 -159.458838
#
#                                                           Phone Number  \
#                       25%        50%        75%       max        count
# has_starbucks
# False         NaN         NaN        NaN        NaN        0
# True          -118.134957 -95.981278 -81.806673 -68.74104  10477
#
#                                                                        \
#                        mean           std min         25%         50%
# has_starbucks
# False         NaN           NaN           NaN NaN         NaN
# True           5.780783e+09  2.371495e+09  0   3605764448  6023310134
#
#                                       Store Number                \
#                       75%         max        count          mean
# has_starbucks
# False         NaN         NaN          0           NaN
# True           7755882411  9899646861  10700        29845.254579
#
#                                                                        Zip  \
#                         std  min      25%      50%       75%    max  count
# has_starbucks
# False         NaN           NaN  NaN      NaN      NaN       NaN     0
# True           31778.498815  101  6629.75  10522.5  73713.75  79797  10700
#
#                                                                          \
#                        mean           std   min          25%        50%
# has_starbucks
# False         NaN           NaN           NaN   NaN          NaN
# True           5.766743e+08  3.477449e+08  1532  272510472.5  638571762
#
#                                        index                                   \
#                        75%        max  count          mean           std  min
# has_starbucks
# False         NaN          NaN         27880  16200.181636  9223.963559   131
# True           920242851.5  999015900  10700  20758.452243  10713.180466  132
#
#                                                                         \
#                     25%      50%       75%    max  count          mean
# has_starbucks
# False          8199.75   16325.5  23907.25  33119  27880  16200.181636
# True           10618.00  25909.0  30416.50  33109  10700  20758.452243
#
#                                                                              \
#                         std  min       25%      50%       75%    max  count
# has_starbucks
# False          9223.963559   131  8199.75   16325.5  23907.25  33119  27880
# True           10713.180466  132  10618.00  25909.0  30416.50  33109  10700
#
#                                                                             \
#                        mean           std min       25%      50%       75%
# has_starbucks
# False          16069.181636  9223.963559   0   8068.75   16194.5  23776.25
# True           20627.452243  10713.180466  1   10487.00  25778.0  30285.50
#
#                                                                             \
#                  max  count         mean          std min      25%     50%
# has_starbucks
# False          32988  0     NaN          NaN          NaN NaN      NaN
# True           32978  10700  5430.311308  3137.111604  0   2717.75  5436.5
#
#                               num_of_sb                                      \
#                    75%    max     count      mean       std min 25% 50% 75%
# has_starbucks
# False         NaN      NaN     27880     0.000000  0.000000  0   0   0   0
# True           8152.25  10842  10700     3.486168  3.070334  1   2   3   4
#
#                   zipcode                                                  \
#               max   count          mean           std   min    25%    50%
# has_starbucks
# False          0   0      NaN           NaN           NaN   NaN    NaN
# True           25  10700   62466.455234  31526.505647  1002  32821  75087
#
#                                zipcode_ex                                \
#                     75%    max      count         mean          std min
# has_starbucks
# False         NaN       NaN     0         NaN          NaN          NaN
# True           92136.25  99901  9796       4089.998367  2257.496747  1
#
#
#                   25%     50%   75%   max
# has_starbucks
# False         NaN     NaN     NaN   NaN
# True           2286.5  3639.5  5502  9998

# %% [markdown]
# ## big differences in means

# %%
contrast = []
for h in df_group.columns.levels[0]:
    group = df_group[h]
    if group.get('count') is not None:
        key = data_dict_all[data_dict_all.field_name==h].field_value.values.tolist()
        row = {
            'header': h,
            'definition': key if not key else key[0],
            'count': group['count'],
            'mean': group['mean'],
            'std': group['std'],
            'min': group['min'],
            '25%': group['25%'],
            '50%': group['50%'],
            '75%': group['75%'],
            'max': group['max'],
            'delta_mean': group['mean'][True] - group['mean'][False]
        }
        contrast.append(row)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-215-0106f506ee89> in <module>()
#       1 contrast = []
# ----> 2 for h in df_group.columns.levels[0]:
#       3     group = df_group[h]
#       4     if group.get('count') is not None:
#       5         key = data_dict_all[data_dict_all.field_name==h].field_value.values.tolist()
#
# NameError: name 'df_group' is not defined

# %%
contrast_sort = sorted(contrast, key=lambda k: k['delta_mean'], reverse=True) 
contrast_sort = filter(lambda x: x['definition'] != [], contrast_sort)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-214-54afabafb84e> in <module>()
# ----> 1 contrast_sort = sorted(contrast, key=lambda k: k['delta_mean'], reverse=True)
#       2 contrast_sort = filter(lambda x: x['definition'] != [], contrast_sort)
#
# NameError: name 'contrast' is not defined

# %%
df_def = pd.DataFrame(contrast_sort)
df_def
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-213-fd0cf502ee21> in <module>()
# ----> 1 df_def = pd.DataFrame(contrast_sort)
#       2 df_def
#
# NameError: name 'contrast_sort' is not defined

# %%
defs = {}
for n,row in data_dict_all.iterrows():
    if not pd.isnull(row[1]):
        defs[row[0]] = row[1]
        
defs['sb_per_capita'] = 'Number of Starbucks Stores per capita'

# %%
df_def[df_def.header.str.contains('HC01_VC03')]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-212-1a6d90ad70a8> in <module>()
# ----> 1 df_def[df_def.header.str.contains('HC01_VC03')]
#
# NameError: name 'df_def' is not defined

# %%
df['HC01_VC03-size-adj'] = np.sqrt(df['HC01_VC03'])
df['num_of_sb-size-adj'] = df['num_of_sb'] * df['num_of_sb'] + df['num_of_sb'] + 1

# %%
df.head()
# Out:
#    sq_miles  HC03_VC96  HC01_VC03  HC01_VC103  HC03_VC67  HC03_VC68  \
# 0  4.439851  36.3       7013       1394        78.0       9.4
# 1  0.524270  56.9       10803      1562        87.6       8.0
# 2  4.944263  53.2       35893      4647        81.4       11.3
# 3  0.327078  80.9       16278      2673        88.3       7.8
# 4  0.678290  70.6       38752      6111        88.6       5.3
#
#    HC03_VC88  HC03_VC49  HC01_VC88  HC03_VC135  HC03_VC136  HC03_VC92  \
# 0  27.3       71.8       1677       1.3         27.3        14.0
# 1  11.9       73.9       668        1.7         20.6        24.5
# 2  10.9       75.4       7247       1.5         21.3        19.5
# 3  5.5        72.6       1120       1.5         31.9        36.9
# 4  9.7        72.5       6560       2.2         31.4        33.6
#
#    HC03_VC12  HC03_VC41  HC03_VC43  HC03_VC161  HC01_VC118  HC03_VC171    zip  \
# 0  9.8        34.4       19.6       11.3        56976       18.7        89109
# 1  6.1        61.3       19.8       10.7        62253       18.9        98101
# 2  7.6        56.0       22.0       11.8        49269       24.3        92101
# 3  3.6        69.7       22.9       5.3         104324      7.2         10017
# 4  6.1        68.5       19.0       8.1         86447       11.8        10019
#
#    grocery_stores  restaurants  manufacturing  tech  colleges  total  \
# 0  156             1536         24             13    32        2556
# 1  228             1124         36             49    80        2919
# 2  184             1828         8              22    208       3982
# 3  260             1344         20             52    240       4963
# 4  344             2192         24             35    232       4939
#
#    shopping_centers  new_homes  hotels  car_dealers  taxis  airport_related  \
# 0  15                18         90      9            6      2
# 1  22                12         162     3            3      4
# 2  38                62         273     3            15     30
# 3  104               34         582     3            6      11
# 4  70                46         699     30           39     5
#
#    starbucks_count  HC01_VC03_sqrt  num_of_sb       City State has_starbucks  \
# 0  25               83.743656       625        Las Vegas  NV    True
# 1  23               103.937481      529        Seattle    WA    True
# 2  23               189.454480      529        San Diego  CA    True
# 3  20               127.585266      400        New York   NY    True
# 4  17               196.855277      289        New York   NY    True
#
#    population_density    predict  qr_predict
# 0  1579.557406         1.713470   2.529413
# 1  20605.800368        3.723462   5.470591
# 2  7259.524804         9.095172   5.764710
# 3  49767.876147        11.295395  15.294128
# 4  57131.899827        8.824595   10.294125

# %%
fg = sns.FacetGrid(data=df, hue='has_starbucks', aspect=1.61,  size=7)
fg.map(pyplot.scatter, 'HC01_VC03', 'HC01_VC103', s=df['starbucks_count']**2, edgecolor="black").add_legend()

# %%
x = 'HC01_VC03'
y = 'HC01_VC103'
fg = sns.FacetGrid(data=df, hue='has_starbucks', aspect=1.61,  size=7)
ax = fg.map(pyplot.scatter, 'HC01_VC03', 'HC01_VC103', s=df['starbucks_count']*6, edgecolor="black").add_legend()
ax.set(xlabel=defs[x], ylabel=defs[y])

# %%
x = 'HC01_VC03'
y = 'HC01_VC103'
fg = sns.FacetGrid(data=df[df.has_starbucks==True], hue='num_of_sb', aspect=1.61,  size=7)
ax = fg.map(pyplot.scatter, x, y).add_legend()
ax.set(xlabel=defs[x], ylabel=defs[y])

# %%
sns.jointplot(x="HC01_VC03", 
              y="HC01_VC103", 
              data=df, 
              kind='scatter', 
              edgecolor="black", 
              c=df['has_starbucks'], 
              size=9)

# fg = sns.FacetGrid(data=df, hue='has_starbucks', aspect=1.61,  size=7)
# fg.map(pyplot.scatter, 'HC01_VC03', 'HC01_VC103', s=df['num_of_sb-size-adj'], edgecolor="black").add_legend()

# %%
x = 'HC03_VC87'
y = 'HC03_VC96'
fg = sns.FacetGrid(data=df, hue='has_starbucks', aspect=1.61,  size=7)
ax = fg.map(pyplot.scatter, x, y, s=df['num_of_sb'], edgecolor="black").add_legend()
ax.set(xlabel=defs[x], ylabel=defs[y])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-105-3b7497e60e9a> in <module>()
#       2 y = 'HC03_VC96'
#       3 fg = sns.FacetGrid(data=df, hue='has_starbucks', aspect=1.61,  size=7)
# ----> 4 ax = fg.map(pyplot.scatter, x, y, s=df['num_of_sb'], edgecolor="black").add_legend()
#       5 ax.set(xlabel=defs[x], ylabel=defs[y])
#
# /usr/local/lib/python2.7/site-packages/seaborn/axisgrid.pyc in map(self, func, *args, **kwargs)
#     715
#     716             # Get the actual data we are going to plot with
# --> 717             plot_data = data_ijk[list(args)]
#     718             if self._dropna:
#     719                 plot_data = plot_data.dropna()
#
# /usr/local/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1961         if isinstance(key, (Series, np.ndarray, Index, list)):
#    1962             # either boolean or fancy integer index
# -> 1963             return self._getitem_array(key)
#    1964         elif isinstance(key, DataFrame):
#    1965             return self._getitem_frame(key)
#
# /usr/local/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_array(self, key)
#    2005             return self.take(indexer, axis=0, convert=False)
#    2006         else:
# -> 2007             indexer = self.ix._convert_to_indexer(key, axis=1)
#    2008             return self.take(indexer, axis=1, convert=True)
#    2009
#
# /usr/local/lib/python2.7/site-packages/pandas/core/indexing.pyc in _convert_to_indexer(self, obj, axis, is_setter)
#    1148                 mask = check == -1
#    1149                 if mask.any():
# -> 1150                     raise KeyError('%s not in index' % objarr[mask])
#    1151
#    1152                 return _values_from_object(indexer)
#
# KeyError: "['HC03_VC87'] not in index"

# %%
x = 'HC03_VC88'
y = 'HC03_VC96'

fg = sns.FacetGrid(data=df, hue='has_starbucks', aspect=1.61,  size=7)
ax = fg.map(pyplot.scatter, x, y, s=df['starbucks_count'], edgecolor="black").add_legend()
_=ax.set(xlabel=defs[x], ylabel=defs[y])

# %%
fg = sns.FacetGrid(data=df, hue='has_starbucks', aspect=1.61,  size=7)
fg.map(pyplot.scatter, 'HC03_VC60', 'HC03_VC52', s=df['starbucks_count'], edgecolor="black").add_legend()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-110-488cfb552a40> in <module>()
#       1 fg = sns.FacetGrid(data=df, hue='has_starbucks', aspect=1.61,  size=7)
# ----> 2 fg.map(pyplot.scatter, 'HC03_VC60', 'HC03_VC52', s=df['starbucks_count'], edgecolor="black").add_legend()
#
# /usr/local/lib/python2.7/site-packages/seaborn/axisgrid.pyc in map(self, func, *args, **kwargs)
#     715
#     716             # Get the actual data we are going to plot with
# --> 717             plot_data = data_ijk[list(args)]
#     718             if self._dropna:
#     719                 plot_data = plot_data.dropna()
#
# /usr/local/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1961         if isinstance(key, (Series, np.ndarray, Index, list)):
#    1962             # either boolean or fancy integer index
# -> 1963             return self._getitem_array(key)
#    1964         elif isinstance(key, DataFrame):
#    1965             return self._getitem_frame(key)
#
# /usr/local/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_array(self, key)
#    2005             return self.take(indexer, axis=0, convert=False)
#    2006         else:
# -> 2007             indexer = self.ix._convert_to_indexer(key, axis=1)
#    2008             return self.take(indexer, axis=1, convert=True)
#    2009
#
# /usr/local/lib/python2.7/site-packages/pandas/core/indexing.pyc in _convert_to_indexer(self, obj, axis, is_setter)
#    1148                 mask = check == -1
#    1149                 if mask.any():
# -> 1150                     raise KeyError('%s not in index' % objarr[mask])
#    1151
#    1152                 return _values_from_object(indexer)
#
# KeyError: "['HC03_VC60' 'HC03_VC52'] not in index"

# %%
x = 'HC03_VC67'
y = 'HC03_VC68'

fg = sns.FacetGrid(data=df, hue='has_starbucks', aspect=1.61,  size=7)

ax = fg.map(pyplot.scatter, x, y, s=df['HC01_VC03-size-adj'], edgecolor="black").add_legend()
ax.set(xlabel=defs[x], ylabel=defs[y])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-123-7070d03b9870> in <module>()
#       4 fg = sns.FacetGrid(data=df, hue='has_starbucks', aspect=1.61,  size=7)
#       5
# ----> 6 ax = fg.map(pyplot.scatter, x, y, s=df['HC01_VC03-size-adj'], edgecolor="black").add_legend()
#       7 ax.set(xlabel=defs[x], ylabel=defs[y])
#
# /usr/local/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1967             return self._getitem_multilevel(key)
#    1968         else:
# -> 1969             return self._getitem_column(key)
#    1970
#    1971     def _getitem_column(self, key):
#
# /usr/local/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1974         # get column
#    1975         if self.columns.is_unique:
# -> 1976             return self._get_item_cache(key)
#    1977
#    1978         # duplicate columns & possible reduce dimensionality
#
# /usr/local/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1089         res = cache.get(item)
#    1090         if res is None:
# -> 1091             values = self._data.get(item)
#    1092             res = self._box_item_values(item, values)
#    1093             cache[item] = res
#
# /usr/local/lib/python2.7/site-packages/pandas/core/internals.pyc in get(self, item, fastpath)
#    3209
#    3210             if not isnull(item):
# -> 3211                 loc = self.items.get_loc(item)
#    3212             else:
#    3213                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /usr/local/lib/python2.7/site-packages/pandas/core/index.pyc in get_loc(self, key, method, tolerance)
#    1757                                  'backfill or nearest lookups')
#    1758             key = _values_from_object(key)
# -> 1759             return self._engine.get_loc(key)
#    1760
#    1761         indexer = self.get_indexer([key], method=method,
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:3979)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:3843)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12265)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12216)()
#
# KeyError: 'HC01_VC03-size-adj'

# %%
from pandas.tools.plotting import scatter_matrix

scatter_matrix(df[['HC03_VC67', 'HC03_VC68']], alpha=0.5, figsize=(8, 8), s=10)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11521b510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x115345750>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x115bb7650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1156f2b10>]], dtype=object)

# %%
df_sample = df.sample(n=10000)

# %%
df.head()
# Out:
#    index              Id   Id2    Geography  HC03_VC04  HC03_VC06  HC03_VC07  \
# 0  131    8600000US01001  1001  ZCTA5 01001  66.7       61.2       5.2
# 1  165    8600000US01062  1062  ZCTA5 01062  68.0       62.0       6.0
# 2  178    8600000US01080  1080  ZCTA5 01080  55.9       50.2       5.7
# 3  180    8600000US01082  1082  ZCTA5 01082  67.7       61.2       6.5
# 4  198    8600000US01107  1107  ZCTA5 01107  50.8       38.3       12.3
#
#    HC03_VC08  HC03_VC09  HC03_VC12  HC03_VC15  HC03_VC17  HC03_VC20  \
# 0  0.3        33.3       7.9        59.9       54.8       68.5
# 1  0.0        32.0       8.8        66.3       61.5       76.0
# 2  0.0        44.1       10.3       56.1       50.4       79.2
# 3  0.0        32.3       9.6        63.3       59.1       68.9
# 4  0.2        49.2       24.3       43.6       34.1       41.5
#
#    HC03_VC23  HC03_VC28  HC03_VC29  HC03_VC30  HC03_VC31  HC03_VC32  \
# 0  80.6       87.4       8.3        0.7        1.3        0.5
# 1  77.3       78.0       8.0        1.9        1.8        2.5
# 2  89.0       81.8       12.2       0.0        6.0        0.0
# 3  74.3       85.4       6.8        0.3        3.7        0.4
# 4  50.9       67.8       13.7       6.7        5.2        1.5
#
#    HC03_VC33 HC01_VC36  HC03_VC41  HC03_VC42  HC03_VC43  HC03_VC44  HC03_VC45  \
# 0  1.8        21.2      34.4       17.7       27.0       11.1       9.8
# 1  7.8        23.5      56.2       12.0       19.7       6.3        5.9
# 2  0.0        28.5      36.0       23.8       17.9       8.0        14.3
# 3  3.4        28.7      30.7       21.2       22.4       9.2        16.5
# 4  5.2        20.1      17.9       40.4       16.2       11.3       14.3
#
#    HC03_VC50  HC03_VC51  HC03_VC52  HC03_VC53  HC03_VC54  HC03_VC55  \
# 3  93.9        6.1         2.4         3.7         2.4         1.4
# 4  82.8        14.9        11.8        3.0         0.9         2.2
#
#    HC03_VC126  HC03_VC131  HC03_VC132  HC03_VC133  HC03_VC134  HC03_VC135  \
# 0  0.6         90.4        87.3        70.2        17.1        3.1
# 1  1.2         93.2        89.7        60.3        29.4        3.5
# 2  0.0         99.1        95.9        84.6        11.3        3.2
# 3  0.0         97.9        97.0        81.0        16.0        0.9
# 4  2.3         89.1        50.0        37.4        12.6        39.1
#
#    HC03_VC136  HC03_VC141  HC03_VC142  HC03_VC171  HC03_VC172  index Brand  \
# 0  9.6         52.0        48.0        86.2        13.8       NaN     None
# 1  6.8         63.0        37.0        89.5        10.5       NaN     None
# 2  0.9         36.8        63.2        95.9        4.1        NaN     None
# 3  2.1         57.7        42.3        97.1        2.9        NaN     None
# 4  10.9        22.9        77.1        27.4        72.6       NaN     None
#
#    Store Number  Name Ownership Type  Facility ID Features - Products  \
# 0 NaN            None  None          NaN           None
# 1 NaN            None  None          NaN           None
# 2 NaN            None  None          NaN           None
# 3 NaN            None  None          NaN           None
# 4 NaN            None  None          NaN           None
#
#   Features - Service Features - Stations  Food Region Venue Type  \
# 0  None               None               NaN           None
# 1  None               None               NaN           None
# 2  None               None               NaN           None
# 3  None               None               NaN           None
# 4  None               None               NaN           None
#
#    Phone Number Location Street Address Street Line 1 Street Line 2  City  \
# 0 NaN            None     NAN            None          None          None
# 1 NaN            None     NAN            None          None          None
# 2 NaN            None     NAN            None          None          None
# 3 NaN            None     NAN            None          None          None
# 4 NaN            None     NAN            None          None          None
#
#   State  Zip Country Coordinates  Latitude  Longitude Insert Date  zipcode  \
# 0  None NaN   None    None       NaN       NaN         None       NaN
# 1  None NaN   None    None       NaN       NaN         None       NaN
# 2  None NaN   None    None       NaN       NaN         None       NaN
# 3  None NaN   None    None       NaN       NaN         None       NaN
# 4  None NaN   None    None       NaN       NaN         None       NaN
#
#    zipcode_ex  num_of_sb has_starbucks  HC01_VC03-size-adj  num_of_sb-size-adj
# 0 NaN          0          False         130.923642          1
# 1 NaN          0          False         104.067286          1
# 2 NaN          0          False         46.647615           1
# 3 NaN          0          False         101.950969          1
# 4 NaN          0          False         108.194270          1

# %%
x = 'HC03_VC88'
y = 'HC03_VC96'

# %%
defs[x]
# Out:
# u'Percent; EDUCATIONAL ATTAINMENT - Population 25 years and over - High school graduate (includes equivalency)'

# %%
geo['Street Address'] = geo['Street Address'].fillna('NAN')
geo['has_starbucks'] = [True if x != 'NAN' else False for x in geo['Street Address']]

# %%
sample_size = 100
df_sample = geo#.sample(n=sample_size)

x = 'HC03_VC88'
y = 'HC03_VC96'
data = []
for n,i in df_sample.iterrows():
    row = {
        'has_starbucks': i.has_starbucks if pd.isnull(i.has_starbucks) is False else None,
        'HC01_VC03': i['HC01_VC03'] if pd.isnull(i.HC01_VC03) is False else None, 
        'HC01_VC103': i['HC01_VC103'] if pd.isnull(i.HC01_VC103) is False else None,
        'num_of_sb': i.num_of_sb if pd.isnull(i.num_of_sb) is False else None,
        'HC03_VC67': i['HC03_VC67'] if pd.isnull(i.HC03_VC67) is False else None,
        'HC03_VC68': i['HC03_VC68'] if pd.isnull(i.HC03_VC68) is False else None,
        'HC03_VC88': i['HC03_VC88'] if pd.isnull(i.HC03_VC88) is False else None,
        'HC03_VC96': i['HC03_VC96'] if pd.isnull(i.HC03_VC96) is False else None,
#         'num_of_sb-size-adj': i['num_of_sb-size-adj'] if pd.isnull(i['num_of_sb-size-adj']) is False else None,
#         'HC01_VC03-size-adj': i['HC01_VC03-size-adj'] if pd.isnull(i['HC01_VC03-size-adj']) is False else None,
        'zipcode': str(i['Id2']) if pd.isnull(i.Id2) is False else None,
        'group': i['State'] if pd.isnull(i['State']) is False else None,
        'subgroup': i['City'] if pd.isnull(i['City']) is False else None,
        'HC03_VC49': i['HC03_VC49'] if pd.isnull(i.HC03_VC49) is False else None, 
        'HC01_VC88': i['HC01_VC88'] if pd.isnull(i.HC01_VC88) is False else None,
        'HC03_VC135': i['HC03_VC135'] if pd.isnull(i.HC03_VC135) is False else None,
        'HC03_VC136':i['HC03_VC136'] if pd.isnull(i.HC03_VC136) is False else None,
        'HC03_VC92':i['HC03_VC92'] if pd.isnull(i.HC03_VC92) is False else None
    }
    if pd.isnull(i.has_starbucks) is False and row['HC01_VC03'] > 0:
        row['sb_per_capita'] = float(row['num_of_sb'])/row['HC01_VC03']
    else:
        row['sb_per_capita'] = 0
    data.append(row)

# %%
data_all = {"data": data, "dataDef": defs, "geojson": geojson}
with open('/Applications/MAMP/htdocs/general/data_sample_'+str(sample_size)+'.json', 'w') as f:
    f.write(json.dumps(data_all))

# %%
# %%sql DB=econ MAKE_GLOBAL=geo
# select distinct
#     count(sb."zipcode") over (
#         partition by sb.zipcode
#     ) as num_of_sb,
#     "HC03_VC96",
#     "HC01_VC03",
#     "HC01_VC103",
#     "HC03_VC67",
#     "HC03_VC68",
#     "HC03_VC88",
#     "HC03_VC49",
#     "HC01_VC88",
#     "HC03_VC135",
#     "HC03_VC136",
#     "HC03_VC92",
#     z."Id2",
#     c.geoid10,
#     ST_AsGeoJSON(c.geom) as the_geom,
#     sb."Street Address",
#     sb."City",
#     sb."State"
# from zip_data z
# join zip_data2 z2 on z2."Id" = z."Id"
# join zip_data3 z3 on z3."Id" = z."Id"
# left join sb_stores sb on sb."zipcode" = z."Id2"
# join cb_2015_us_zcta510_500k c on c.geoid10::bigint = z."Id2"
# where sb."State" = 'TN'
#     and "HC01_VC03" > 0
# order by num_of_sb desc
# Out:
#         <style>
#         .input {
#             position:relative;
#         }
#         #childDiv41ed72f6-44a1-4fa9-8ad2-e910b431e5d1 {
#             width: 90%;
#             position:absolute;
#         }
#         #table41ed72f6-44a1-4fa9-8ad2-e910b431e5d1{
#             padding-top: 40px;
#         }
#         </style>
#         <div class="row" id="childDiv41ed72f6-44a1-4fa9-8ad2-e910b431e5d1">
#             <div class="btn-group col-md-3">
#                 <button id="explain" title="Explain Analyze Graph" onclick="explain('__EXPLAIN_GRAPH__')" type="button" class="btn btn-info btn-sm"><p class="fa fa-code-fork fa-rotate-270"</p></button>
#                 <button id="explain" title="Explain Analyze" onclick="explain('__EXPLAIN__')" type="button" class="btn btn-info btn-sm"><p class="fa fa-info-circle"</p></button>
#                 <button type="button" title="Execute" onclick="run()" class="btn btn-success btn-sm"><p class="fa fa-play"></p></button>
#                 <button type="button" title="Execute and Return Data as Variable" onclick="getData()" class="btn btn-success btn-sm"><p class="">var</p></button>
#                 <button id="saveData41ed72f6-44a1-4fa9-8ad2-e910b431e5d1" title="Save" class="btn btn-success btn-sm disabled" type="button"><p class="fa fa-save"</p></button>
#                 <button id="cancelQuery41ed72f6-44a1-4fa9-8ad2-e910b431e5d1" title="Cancel Query" class="btn btn-danger btn-sm" type="button"><p class="fa fa-stop"</p></button>
#             </div>
#             <div id="engineButtons41ed72f6-44a1-4fa9-8ad2-e910b431e5d1" class="btn-group col-md-4"></div>
#             <div id="tableData41ed72f6-44a1-4fa9-8ad2-e910b431e5d1"></div>
#         </div>
#         <div class="table" id="table41ed72f6-44a1-4fa9-8ad2-e910b431e5d1"></div>
#         <script type="text/Javascript">
#
#             (function($) {
#                 var MutationObserver = window.MutationObserver || window.WebKitMutationObserver || window.MozMutationObserver;
#
#                 $.fn.attrchange = function(callback) {
#                     if (MutationObserver) {
#                         var options = {
#                             subtree: false,
#                             attributes: true
#                         };
#
#                         var observer = new MutationObserver(function(mutations) {
#                             mutations.forEach(function(e) {
#                                 callback.call(e.target, e.attributeName);
#                             });
#                         });
#
#                         return this.each(function() {
#                             observer.observe(this, options);
#                         });
#
#                     }
#                 }
#             } )(jQuery);
#             $("#childDiv41ed72f6-44a1-4fa9-8ad2-e910b431e5d1").parents('.code_cell').attrchange(function(attrName){
#                 if (attrName=='class'){
#                     if ($(this).hasClass('unselected')){
#                         $("#childDiv41ed72f6-44a1-4fa9-8ad2-e910b431e5d1").find('button').each(function(i, obj){
#                             $(obj).addClass('disabled');
#                         });
#                     } else if ($(this).hasClass('selected')){
#                         $("#childDiv41ed72f6-44a1-4fa9-8ad2-e910b431e5d1").find('button').each(function(i, obj){
#                             $(obj).removeClass('disabled');
#                         });
#                     }
#                 }
#             });
#
#
#
#             var engines = JSON.parse(`{"PRODALL": {"engine": "postgresql://phdba:RXBpJd8fH7BTUDZdO8qB@phteam-prod.ccmhg5j69wvw.us-east-1.rds.amazonaws.com:5432/", "caution_level": "danger", "order": 3}, "DATALAKE": {"engine": "postgresql://tim.dobbins:2F5HVimo@db.phdatalake.perceptionhealth.com/", "caution_level": "danger", "order": 4}, "PROD": {"engine": "postgresql://phdba:RXBpJd8fH7BTUDZdO8qB@phteam-prod.ccmhg5j69wvw.us-east-1.rds.amazonaws.com:5432/", "caution_level": "danger", "order": 2}, "LOCAL": {"engine": "postgresql://phdba:RXBpJd8fH7BTUDZdO8qB@localhost:5432/", "caution_level": "warning", "order": 0}, "DEV": {"engine": "postgresql://phTeam:4zHam9MLDC@db.dev.phteam.perceptionhealth.com/", "caution_level": "warning", "order": 1}}`);
#
#             var sortedEngineKeys = Object.keys(engines).sort(function(a,b){
#                 return engines[a].order - engines[b].order;
#             });
#
#             var sortedEngines = sortedEngineKeys.reduce(function(output, row, idx){
#                 engines[row]['key'] = row;
#                 output.push(engines[row]);
#                 return output;
#             }, []);
#
#             var engineButtons = '';
#             for (var engine in sortedEngines){
#                 var engineKey = sortedEngines[engine].key;
#                 var warningLabel = sortedEngines[engine].caution_level;
#                 engineButtons += '<button title="Switch Engine" onclick="switchEngines('+"'"+engineKey+"'"+')" class="btn btn-'+warningLabel+' btn-sm">'+engineKey+'</button>';
#             };
#
#            $("#engineButtons41ed72f6-44a1-4fa9-8ad2-e910b431e5d1").append(engineButtons);
#
#            $("#cancelQuery41ed72f6-44a1-4fa9-8ad2-e910b431e5d1").on('click', function(){
#                if ($("#cancelQuery41ed72f6-44a1-4fa9-8ad2-e910b431e5d1").hasClass('disabled')){
#                    console.log('alread stopped or finished query...');
#                } else {
#                    cancelQuery("c673bd18-a83c-4cd8-a7eb-c6a25a0dd9c3");
#                    //$("#cancelQuery41ed72f6-44a1-4fa9-8ad2-e910b431e5d1").addClass('disabled')
#                }
#            });
#
#             function explain(gloVar){
#                 var command =  `__SQLCell_GLOBAL_VARS__.`+gloVar+` = True`;
#                 console.log(command);
#                 var kernel = IPython.notebook.kernel;
#                 kernel.execute(command);
#                 IPython.notebook.execute_cell();
#             };
#
#             function run(){
#                 IPython.notebook.execute_cell();
#                 $.get('/api/contents', function(data){
#                     console.log(data);
#                 });
#             };
#
#             function cancelQuery(applicationID){
#                 IPython.notebook.kernel.execute('__SQLCell_GLOBAL_VARS__().kill_last_pid_on_new_thread(__SQLCell_GLOBAL_VARS__.jupyter_id, "econ", "41ed72f6-44a1-4fa9-8ad2-e910b431e5d1")',
#                     {
#                         iopub: {
#                             output: function(response) {
#                                 var $table = $("#table41ed72f6-44a1-4fa9-8ad2-e910b431e5d1").parent();
#                                 console.log(response);
#                                 if (response.content && response.content.text){
#                                     $table.append('<h5 style="color:#d9534f;">'+response.content.text+'</h5>')
#                                 } else if (response.content && response.content.evalue){
#                                     $table.append('<h5 style="color:#d9534f;">'+response.content.evalue+'</h5>');
#                                 }
#                             }
#                         }
#                     },
#                     {
#                         silent: false,
#                         store_history: false,
#                         stop_on_error: true
#                     }
#                 );
#             };
#
#             function getData(){
#                 var command = `__SQLCell_GLOBAL_VARS__.__GETDATA__ = True`;
#                 var kernel = IPython.notebook.kernel;
#                 kernel.execute(command);
#                 IPython.notebook.execute_cell();
#             };
#
#             function saveData(data, filename){
#                 var path = $('#path').val() || './'
#                 var command = `__SQLCell_GLOBAL_VARS__.__SAVEDATA__, PATH = True,'`+path+`'`;
#                 var kernel = IPython.notebook.kernel;
#                 kernel.execute(command);
#                 //IPython.notebook.execut

# %%
geojson = {}
for row in geo:   
    geojson[row.geoid10] = [
        dict(zip(i.keys(), i)) 
        if 'MultiPolygon' in str(i) else json.loads(i) 
        for i in geo
    ][0]
    geojson[row.geoid10]['the_geom'] = json.loads(geojson[row.geoid10]['the_geom'])

# %%
# %%sql DB=econ
# \d zip_data_sb
# /* alter table zip_data_sb alter column "HC01_VC118" type int USING "HC01_VC118"::integer */
# /* update zip_data_sb set "HC01_VC118" = 0 where "HC01_VC118" = ''; */
# /* update zip_data_sb set "HC01_VC118" = 0 where "HC01_VC118" = 'N'; */
# Out:
#         <style>
#         .input {
#             position:relative;
#         }
#         #childDiva9bf3392-56b6-46fa-8aba-12e7be826088 {
#             width: 90%;
#             position:absolute;
#         }
#         #tablea9bf3392-56b6-46fa-8aba-12e7be826088{
#             padding-top: 40px;
#         }
#         </style>
#         <div class="row" id="childDiva9bf3392-56b6-46fa-8aba-12e7be826088">
#             <div class="btn-group col-md-3">
#                 <button id="explain" title="Explain Analyze Graph" onclick="explain('__EXPLAIN_GRAPH__')" type="button" class="btn btn-info btn-sm"><p class="fa fa-code-fork fa-rotate-270"</p></button>
#                 <button id="explain" title="Explain Analyze" onclick="explain('__EXPLAIN__')" type="button" class="btn btn-info btn-sm"><p class="fa fa-info-circle"</p></button>
#                 <button type="button" title="Execute" onclick="run()" class="btn btn-success btn-sm"><p class="fa fa-play"></p></button>
#                 <button type="button" title="Execute and Return Data as Variable" onclick="getData()" class="btn btn-success btn-sm"><p class="">var</p></button>
#                 <button id="saveDataa9bf3392-56b6-46fa-8aba-12e7be826088" title="Save" class="btn btn-success btn-sm disabled" type="button"><p class="fa fa-save"</p></button>
#                 <button id="cancelQuerya9bf3392-56b6-46fa-8aba-12e7be826088" title="Cancel Query" class="btn btn-danger btn-sm" type="button"><p class="fa fa-stop"</p></button>
#             </div>
#             <div id="engineButtonsa9bf3392-56b6-46fa-8aba-12e7be826088" class="btn-group col-md-4"></div>
#             <div id="tableDataa9bf3392-56b6-46fa-8aba-12e7be826088"></div>
#         </div>
#         <div class="table" id="tablea9bf3392-56b6-46fa-8aba-12e7be826088"></div>
#         <script type="text/Javascript">
#
#             (function($) {
#                 var MutationObserver = window.MutationObserver || window.WebKitMutationObserver || window.MozMutationObserver;
#
#                 $.fn.attrchange = function(callback) {
#                     if (MutationObserver) {
#                         var options = {
#                             subtree: false,
#                             attributes: true
#                         };
#
#                         var observer = new MutationObserver(function(mutations) {
#                             mutations.forEach(function(e) {
#                                 callback.call(e.target, e.attributeName);
#                             });
#                         });
#
#                         return this.each(function() {
#                             observer.observe(this, options);
#                         });
#
#                     }
#                 }
#             } )(jQuery);
#             $("#childDiva9bf3392-56b6-46fa-8aba-12e7be826088").parents('.code_cell').attrchange(function(attrName){
#                 if (attrName=='class'){
#                     if ($(this).hasClass('unselected')){
#                         $("#childDiva9bf3392-56b6-46fa-8aba-12e7be826088").find('button').each(function(i, obj){
#                             $(obj).addClass('disabled');
#                         });
#                     } else if ($(this).hasClass('selected')){
#                         $("#childDiva9bf3392-56b6-46fa-8aba-12e7be826088").find('button').each(function(i, obj){
#                             $(obj).removeClass('disabled');
#                         });
#                     }
#                 }
#             });
#
#
#
#             var engines = JSON.parse(`{"PRODALL": {"engine": "postgresql://phdba:RXBpJd8fH7BTUDZdO8qB@phteam-prod.ccmhg5j69wvw.us-east-1.rds.amazonaws.com:5432/", "caution_level": "danger", "order": 3}, "DATALAKE": {"engine": "postgresql://tim.dobbins:2F5HVimo@db.phdatalake.perceptionhealth.com/", "caution_level": "danger", "order": 4}, "PROD": {"engine": "postgresql://phdba:RXBpJd8fH7BTUDZdO8qB@phteam-prod.ccmhg5j69wvw.us-east-1.rds.amazonaws.com:5432/", "caution_level": "danger", "order": 2}, "LOCAL": {"engine": "postgresql://phdba:RXBpJd8fH7BTUDZdO8qB@localhost:5432/", "caution_level": "warning", "order": 0}, "DEV": {"engine": "postgresql://phTeam:4zHam9MLDC@db.dev.phteam.perceptionhealth.com/", "caution_level": "warning", "order": 1}}`);
#
#             var sortedEngineKeys = Object.keys(engines).sort(function(a,b){
#                 return engines[a].order - engines[b].order;
#             });
#
#             var sortedEngines = sortedEngineKeys.reduce(function(output, row, idx){
#                 engines[row]['key'] = row;
#                 output.push(engines[row]);
#                 return output;
#             }, []);
#
#             var engineButtons = '';
#             for (var engine in sortedEngines){
#                 var engineKey = sortedEngines[engine].key;
#                 var warningLabel = sortedEngines[engine].caution_level;
#                 engineButtons += '<button title="Switch Engine" onclick="switchEngines('+"'"+engineKey+"'"+')" class="btn btn-'+warningLabel+' btn-sm">'+engineKey+'</button>';
#             };
#
#            $("#engineButtonsa9bf3392-56b6-46fa-8aba-12e7be826088").append(engineButtons);
#
#            $("#cancelQuerya9bf3392-56b6-46fa-8aba-12e7be826088").on('click', function(){
#                if ($("#cancelQuerya9bf3392-56b6-46fa-8aba-12e7be826088").hasClass('disabled')){
#                    console.log('alread stopped or finished query...');
#                } else {
#                    cancelQuery("dd642394-41b0-4494-b428-cb933a72f6ea");
#                    //$("#cancelQuerya9bf3392-56b6-46fa-8aba-12e7be826088").addClass('disabled')
#                }
#            });
#
#             function explain(gloVar){
#                 var command =  `__SQLCell_GLOBAL_VARS__.`+gloVar+` = True`;
#                 console.log(command);
#                 var kernel = IPython.notebook.kernel;
#                 kernel.execute(command);
#                 IPython.notebook.execute_cell();
#             };
#
#             function run(){
#                 IPython.notebook.execute_cell();
#                 $.get('/api/contents', function(data){
#                     console.log(data);
#                 });
#             };
#
#             function cancelQuery(applicationID){
#                 IPython.notebook.kernel.execute('__SQLCell_GLOBAL_VARS__().kill_last_pid_on_new_thread(__SQLCell_GLOBAL_VARS__.jupyter_id, "econ", "a9bf3392-56b6-46fa-8aba-12e7be826088")',
#                     {
#                         iopub: {
#                             output: function(response) {
#                                 var $table = $("#tablea9bf3392-56b6-46fa-8aba-12e7be826088").parent();
#                                 console.log(response);
#                                 if (response.content && response.content.text){
#                                     $table.append('<h5 style="color:#d9534f;">'+response.content.text+'</h5>')
#                                 } else if (response.content && response.content.evalue){
#                                     $table.append('<h5 style="color:#d9534f;">'+response.content.evalue+'</h5>');
#                                 }
#                             }
#                         }
#                     },
#                     {
#                         silent: false,
#                         store_history: false,
#                         stop_on_error: true
#                     }
#                 );
#             };
#
#             function getData(){
#                 var command = `__SQLCell_GLOBAL_VARS__.__GETDATA__ = True`;
#                 var kernel = IPython.notebook.kernel;
#                 kernel.execute(command);
#                 IPython.notebook.execute_cell();
#             };
#
#             function saveData(data, filename){
#                 var path = $('#path').val() || './'
#                 var command = `__SQLCell_GLOBAL_VARS__.__SAVEDATA__, PATH = True,'`+path+`'`;
#                 var kernel = IPython.notebook.kernel;
#                 kernel.execute(command);
#                 //IPython.notebook.execut

# %%
del df

# %%
# %%sql DB=econ MAKE_GLOBAL=df NOTIFY=3
# SELECT *,
#     CASE
#         WHEN num_of_sb > 0 THEN true
#         ELSE false
#     end AS has_starbucks
# FROM (
#     SELECT DISTINCT
#         ST_Area(geom::geography) / 1609.34^2 AS sq_miles,
#         "HC03_VC96",
#         "HC01_VC03",
#         "HC01_VC103",
#         "HC03_VC67",
#         "HC03_VC68",
#         "HC03_VC88",
#         "HC03_VC49",
#         "HC01_VC88",
#         "HC03_VC135",
#         "HC03_VC136",
#         "HC03_VC92",
#         z."HC03_VC12",
#         z."HC03_VC41",
#         "HC03_VC43",
#         "HC03_VC161",
#         "HC01_VC118",
#         "HC03_VC87",
#         z."HC03_VC171",
#         zn.*,
#         z.starbucks_count,
#         sqrt("HC01_VC03") as "HC01_VC03_sqrt",
#         count(sb."zipcode") over (
#             partition by sb.zipcode
#         ) as num_of_sb,
#         sb."City",
#         sb."State",
#         sb."Latitude",
#         sb."Longitude"
#     from zip_data_sb z
#     join zip_data2 z2 on z2."Id" = z."Id"
#     join zip_data3 z3 on z3."Id" = z."Id"
#     left join sb_stores sb on sb."zipcode" = z."Id2"
#     join cb_2015_us_zcta510_500k c on c.geoid10::bigint = z."Id2"
#     join (
#         select zip,
#             sum(case when naics ~ '^445' then est end)::bigint as "grocery_stores",
#             sum(case when naics ~ '^722' then est end)::bigint as "restaurants",
#             sum(case when naics ~ '^311' then est end)::bigint as "manufacturing",
#             sum(case when naics ~ '^54171' or naics = '518210' then est end)::bigint as "tech",
#             sum(case when naics ~ '^611' then est end)::bigint as "colleges",
#             sum(case when naics = '------' then est end)::bigint as "total",
#             sum(case when naics = '531120' then est end)::bigint as "shopping_centers",
#             sum(case when naics ~ '^23611' then est end)::bigint as "new_homes",
#             sum(case when naics ~ '^5311' then est end)::bigint as "hotels",
#             sum(case when naics ~ '^4411' then est end)::bigint as "car_dealers",
#             sum(case when naics ~ '^4853' then est end)::bigint as "taxis",
#             sum(case when naics = '481111'
#                 or naics in ('485999', '488119', '488190') then est end)::bigint as "airport_related"
#         from zip_to_naics
#         group by zip
#     ) zn on zn.zip = z."Id2"
#     where "HC01_VC03" > 0
#     order by num_of_sb desc
# ) s
# Out:
#         <style>
#         .input {
#             position:relative;
#         }
#         #childDivbd1b9bcb-7c55-4765-932d-17d7497ecd1d {
#             width: 90%;
#             position:absolute;
#         }
#         #tablebd1b9bcb-7c55-4765-932d-17d7497ecd1d{
#             padding-top: 40px;
#         }
#         </style>
#         <div class="row" id="childDivbd1b9bcb-7c55-4765-932d-17d7497ecd1d">
#             <div class="btn-group col-md-3">
#                 <button id="explain" title="Explain Analyze Graph" onclick="explain('__EXPLAIN_GRAPH__')" type="button" class="btn btn-info btn-sm"><p class="fa fa-code-fork fa-rotate-270"</p></button>
#                 <button id="explain" title="Explain Analyze" onclick="explain('__EXPLAIN__')" type="button" class="btn btn-info btn-sm"><p class="fa fa-info-circle"</p></button>
#                 <button type="button" title="Execute" onclick="run()" class="btn btn-success btn-sm"><p class="fa fa-play"></p></button>
#                 <button type="button" title="Execute and Return Data as Variable" onclick="getData()" class="btn btn-success btn-sm"><p class="">var</p></button>
#                 <button id="saveDatabd1b9bcb-7c55-4765-932d-17d7497ecd1d" title="Save" class="btn btn-success btn-sm disabled" type="button"><p class="fa fa-save"</p></button>
#                 <button id="cancelQuerybd1b9bcb-7c55-4765-932d-17d7497ecd1d" title="Cancel Query" class="btn btn-danger btn-sm" type="button"><p class="fa fa-stop"</p></button>
#             </div>
#             <div id="engineButtonsbd1b9bcb-7c55-4765-932d-17d7497ecd1d" class="btn-group col-md-4"></div>
#             <div id="tableDatabd1b9bcb-7c55-4765-932d-17d7497ecd1d"></div>
#         </div>
#         <div class="table" id="tablebd1b9bcb-7c55-4765-932d-17d7497ecd1d"></div>
#         <script type="text/Javascript">
#
#             (function($) {
#                 var MutationObserver = window.MutationObserver || window.WebKitMutationObserver || window.MozMutationObserver;
#
#                 $.fn.attrchange = function(callback) {
#                     if (MutationObserver) {
#                         var options = {
#                             subtree: false,
#                             attributes: true
#                         };
#
#                         var observer = new MutationObserver(function(mutations) {
#                             mutations.forEach(function(e) {
#                                 callback.call(e.target, e.attributeName);
#                             });
#                         });
#
#                         return this.each(function() {
#                             observer.observe(this, options);
#                         });
#
#                     }
#                 }
#             } )(jQuery);
#             $("#childDivbd1b9bcb-7c55-4765-932d-17d7497ecd1d").parents('.code_cell').attrchange(function(attrName){
#                 if (attrName=='class'){
#                     if ($(this).hasClass('unselected')){
#                         $("#childDivbd1b9bcb-7c55-4765-932d-17d7497ecd1d").find('button').each(function(i, obj){
#                             $(obj).addClass('disabled');
#                         });
#                     } else if ($(this).hasClass('selected')){
#                         $("#childDivbd1b9bcb-7c55-4765-932d-17d7497ecd1d").find('button').each(function(i, obj){
#                             $(obj).removeClass('disabled');
#                         });
#                     }
#                 }
#             });
#
#
#
#             var engines = JSON.parse(`{"PRODALL": {"engine": "postgresql://phdba:RXBpJd8fH7BTUDZdO8qB@phteam-prod.ccmhg5j69wvw.us-east-1.rds.amazonaws.com:5432/", "caution_level": "danger", "order": 3}, "DATALAKE": {"engine": "postgresql://tim.dobbins:2F5HVimo@db.phdatalake.perceptionhealth.com/", "caution_level": "danger", "order": 4}, "PROD": {"engine": "postgresql://phdba:RXBpJd8fH7BTUDZdO8qB@phteam-prod.ccmhg5j69wvw.us-east-1.rds.amazonaws.com:5432/", "caution_level": "danger", "order": 2}, "LOCAL": {"engine": "postgresql://phdba:RXBpJd8fH7BTUDZdO8qB@localhost:5432/", "caution_level": "warning", "order": 0}, "DEV": {"engine": "postgresql://phTeam:4zHam9MLDC@db.dev.phteam.perceptionhealth.com/", "caution_level": "warning", "order": 1}}`);
#
#             var sortedEngineKeys = Object.keys(engines).sort(function(a,b){
#                 return engines[a].order - engines[b].order;
#             });
#
#             var sortedEngines = sortedEngineKeys.reduce(function(output, row, idx){
#                 engines[row]['key'] = row;
#                 output.push(engines[row]);
#                 return output;
#             }, []);
#
#             var engineButtons = '';
#             for (var engine in sortedEngines){
#                 var engineKey = sortedEngines[engine].key;
#                 var warningLabel = sortedEngines[engine].caution_level;
#                 engineButtons += '<button title="Switch Engine" onclick="switchEngines('+"'"+engineKey+"'"+')" class="btn btn-'+warningLabel+' btn-sm">'+engineKey+'</button>';
#             };
#
#            $("#engineButtonsbd1b9bcb-7c55-4765-932d-17d7497ecd1d").append(engineButtons);
#
#            $("#cancelQuerybd1b9bcb-7c55-4765-932d-17d7497ecd1d").on('click', function(){
#                if ($("#cancelQuerybd1b9bcb-7c55-4765-932d-17d7497ecd1d").hasClass('disabled')){
#                    console.log('alread stopped or finished query...');
#                } else {
#                    cancelQuery("d0f9d232-4529-4b93-be06-dd30c542260c");
#                    //$("#cancelQuerybd1b9bcb-7c55-4765-932d-17d7497ecd1d").addClass('disabled')
#                }
#            });
#
#             function explain(gloVar){
#                 var command =  `__SQLCell_GLOBAL_VARS__.`+gloVar+` = True`;
#                 console.log(command);
#                 var kernel = IPython.notebook.kernel;
#                 kernel.execute(command);
#                 IPython.notebook.execute_cell();
#             };
#
#             function run(){
#                 IPython.notebook.execute_cell();
#                 $.get('/api/contents', function(data){
#                     console.log(data);
#                 });
#             };
#
#             function cancelQuery(applicationID){
#                 IPython.notebook.kernel.execute('__SQLCell_GLOBAL_VARS__().kill_last_pid_on_new_thread(__SQLCell_GLOBAL_VARS__.jupyter_id, "econ", "bd1b9bcb-7c55-4765-932d-17d7497ecd1d")',
#                     {
#                         iopub: {
#                             output: function(response) {
#                                 var $table = $("#tablebd1b9bcb-7c55-4765-932d-17d7497ecd1d").parent();
#                                 console.log(response);
#                                 if (response.content && response.content.text){
#                                     $table.append('<h5 style="color:#d9534f;">'+response.content.text+'</h5>')
#                                 } else if (response.content && response.content.evalue){
#                                     $table.append('<h5 style="color:#d9534f;">'+response.content.evalue+'</h5>');
#                                 }
#                             }
#                         }
#                     },
#                     {
#                         silent: false,
#                         store_history: false,
#                         stop_on_error: true
#                     }
#                 );
#             };
#
#             function getData(){
#                 var command = `__SQLCell_GLOBAL_VARS__.__GETDATA__ = True`;
#                 var kernel = IPython.notebook.kernel;
#                 kernel.execute(command);
#                 IPython.notebook.execute_cell();
#             };
#
#             function saveData(data, filename){
#                 var path = $('#path').val() || './'
#                 var command = `__SQLCell_GLOBAL_VARS__.__SAVEDATA__, PATH = True,'`+path+`'`;
#                 var kernel = IPython.notebook.kernel;
#                 kernel.execute(command);
#                 //IPython.notebook.execut

# %%
df['population_density'] = df['HC01_VC03'] / df['sq_miles']

# %%
x = 'HC01_VC03_ln'
y = 'num_of_sb'

df_filtered = df

fg = sns.FacetGrid(data=df_filtered, hue='has_starbucks', aspect=1.61,  size=7)

ax = fg.map(pyplot.scatter, x, y, edgecolor="black", s=df_filtered['num_of_sb']).add_legend()
# ax.set(xlabel=defs[x], ylabel=defs[y])

# %%
zipcode_to_fips = pd.read_csv('/Users/tdobbins/Downloads/BP_2014_00CZ2/BP_2014_00CZ2.csv', header=1)

# %%
zipcode_to_fips.head()
# Out:
#   Geographic identifier code    Id2   Geographic area name  Id  \
# 0  8610000US35004             35004  ZIP 35004 (Moody, AL) NaN
# 1  8610000US35004             35004  ZIP 35004 (Moody, AL) NaN
# 2  8610000US35004             35004  ZIP 35004 (Moody, AL) NaN
# 3  8610000US35004             35004  ZIP 35004 (Moody, AL) NaN
# 4  8610000US35004             35004  ZIP 35004 (Moody, AL) NaN
#
#   2012 NAICS code Meaning of 2012 NAICS code  Id.1  Year  \
# 0  00              Total for all sectors     NaN    2014
# 1  00              Total for all sectors     NaN    2014
# 2  00              Total for all sectors     NaN    2014
# 3  00              Total for all sectors     NaN    2014
# 4  00              Total for all sectors     NaN    2014
#
#    Employment size of establishment  \
# 0  1
# 1  212
# 2  220
# 3  230
# 4  241
#
#   Meaning of Employment size of establishment  Number of establishments
# 0  All establishments                          177
# 1  Establishments with 1 to 4 employees        92
# 2  Establishments with 5 to 9 employees        34
# 3  Establishments with 10 to 19 employees      25
# 4  Establishments with 20 to 49 employees      14

# %%
# zip14 = pd.read_csv('/Users/tdobbins/Downloads/zbp14detail.txt')

# zip14.to_sql('zip_to_naics', engine, if_exists='replace', index=True, chunksize=1000)

# %%
# zipcode_to_fips.to_sql('business_data', engine, if_exists='replace', index=True)

# %%
zbp = pd.read_csv('/Users/tdobbins/Downloads/zbp12-13totals.csv', header=None)

zbp.to_sql('zbp', engine, if_exists='replace', index=True)

# %%
zbp.columns = [i.replace(' ','').replace('-','_') for i in """ZIP -- ZIP code
City -- city name
County -- county name
St - state USPS code
Establishments -- 2012
Establishments -- 2013
Establishments -- 2012-2013 change
Establishments -- 2012-2013 percent change
F1 -- 2012 Data Suppression Flag
F2 -- 2012 Total Mid-March Employees Noise Flag
Employment -- Mid-March 2012
F3 -- 2013 Data Suppression Flag
F4 -- 2013 Total Mid-March Employees Noise Flag
Employment -- Mid-March 2013
Employment -- 2012-2013 change
Employment -- 2012-2013 percent change
F5 -- Total First Quarter Payroll Noise Flag -- 2012
1st Quarter Payroll -- 2012
F6 -- Total First Quarter Payroll Noise Flag -- 2013
1st Quarter Payroll -- 2013
1st Quarter Payroll -- 2012-2013 change
1st Quarter Payroll -- 2012-2013 percent change
F7 -- Total Annual Payroll Noise Flag -- 2013
Annual Payroll -- 2012
F8 -- Total Annual Payroll Noise Flag --2013
Annual Payroll -- 2013
Annual Payroll -- 2012-2013 change
Annual Payroll -- 2012-2013 percent change""".split('\n')]

# %%
# %%sql DB=econ
# /* CREATE TABLE zip_data_sb AS */
#     select z."Id2",
#         count(sb."zipcode") over (
#             partition by sb.zipcode
#         ) as starbucks_count,
#         sb.*
#     from zip_data z
#     left join sb_stores sb on sb."zipcode" = z."Id2"
#     order by starbucks_count desc
# Out:
#         <style>
#         .input {
#             position:relative;
#         }
#         #childDiv9d85dfd3-6fd2-4169-a081-969b9d7b92ec {
#             width: 90%;
#             position:absolute;
#         }
#         #table9d85dfd3-6fd2-4169-a081-969b9d7b92ec{
#             padding-top: 40px;
#         }
#         </style>
#         <div class="row" id="childDiv9d85dfd3-6fd2-4169-a081-969b9d7b92ec">
#             <div class="btn-group col-md-3">
#                 <button id="explain" title="Explain Analyze Graph" onclick="explain('__EXPLAIN_GRAPH__')" type="button" class="btn btn-info btn-sm"><p class="fa fa-code-fork fa-rotate-270"</p></button>
#                 <button id="explain" title="Explain Analyze" onclick="explain('__EXPLAIN__')" type="button" class="btn btn-info btn-sm"><p class="fa fa-info-circle"</p></button>
#                 <button type="button" title="Execute" onclick="run()" class="btn btn-success btn-sm"><p class="fa fa-play"></p></button>
#                 <button type="button" title="Execute and Return Data as Variable" onclick="getData()" class="btn btn-success btn-sm"><p class="">var</p></button>
#                 <button id="saveData9d85dfd3-6fd2-4169-a081-969b9d7b92ec" title="Save" class="btn btn-success btn-sm disabled" type="button"><p class="fa fa-save"</p></button>
#                 <button id="cancelQuery9d85dfd3-6fd2-4169-a081-969b9d7b92ec" title="Cancel Query" class="btn btn-danger btn-sm" type="button"><p class="fa fa-stop"</p></button>
#             </div>
#             <div id="engineButtons9d85dfd3-6fd2-4169-a081-969b9d7b92ec" class="btn-group col-md-4"></div>
#             <div id="tableData9d85dfd3-6fd2-4169-a081-969b9d7b92ec"></div>
#         </div>
#         <div class="table" id="table9d85dfd3-6fd2-4169-a081-969b9d7b92ec"></div>
#         <script type="text/Javascript">
#
#             (function($) {
#                 var MutationObserver = window.MutationObserver || window.WebKitMutationObserver || window.MozMutationObserver;
#
#                 $.fn.attrchange = function(callback) {
#                     if (MutationObserver) {
#                         var options = {
#                             subtree: false,
#                             attributes: true
#                         };
#
#                         var observer = new MutationObserver(function(mutations) {
#                             mutations.forEach(function(e) {
#                                 callback.call(e.target, e.attributeName);
#                             });
#                         });
#
#                         return this.each(function() {
#                             observer.observe(this, options);
#                         });
#
#                     }
#                 }
#             } )(jQuery);
#             $("#childDiv9d85dfd3-6fd2-4169-a081-969b9d7b92ec").parents('.code_cell').attrchange(function(attrName){
#                 if (attrName=='class'){
#                     if ($(this).hasClass('unselected')){
#                         $("#childDiv9d85dfd3-6fd2-4169-a081-969b9d7b92ec").find('button').each(function(i, obj){
#                             $(obj).addClass('disabled');
#                         });
#                     } else if ($(this).hasClass('selected')){
#                         $("#childDiv9d85dfd3-6fd2-4169-a081-969b9d7b92ec").find('button').each(function(i, obj){
#                             $(obj).removeClass('disabled');
#                         });
#                     }
#                 }
#             });
#
#
#
#             var engines = JSON.parse(`{"PRODALL": {"engine": "postgresql://phdba:RXBpJd8fH7BTUDZdO8qB@phteam-prod.ccmhg5j69wvw.us-east-1.rds.amazonaws.com:5432/", "caution_level": "danger", "order": 3}, "DATALAKE": {"engine": "postgresql://tim.dobbins:2F5HVimo@db.phdatalake.perceptionhealth.com/", "caution_level": "danger", "order": 4}, "PROD": {"engine": "postgresql://phdba:RXBpJd8fH7BTUDZdO8qB@phteam-prod.ccmhg5j69wvw.us-east-1.rds.amazonaws.com:5432/", "caution_level": "danger", "order": 2}, "LOCAL": {"engine": "postgresql://phdba:RXBpJd8fH7BTUDZdO8qB@localhost:5432/", "caution_level": "warning", "order": 0}, "DEV": {"engine": "postgresql://phTeam:4zHam9MLDC@db.dev.phteam.perceptionhealth.com/", "caution_level": "warning", "order": 1}}`);
#
#             var sortedEngineKeys = Object.keys(engines).sort(function(a,b){
#                 return engines[a].order - engines[b].order;
#             });
#
#             var sortedEngines = sortedEngineKeys.reduce(function(output, row, idx){
#                 engines[row]['key'] = row;
#                 output.push(engines[row]);
#                 return output;
#             }, []);
#
#             var engineButtons = '';
#             for (var engine in sortedEngines){
#                 var engineKey = sortedEngines[engine].key;
#                 var warningLabel = sortedEngines[engine].caution_level;
#                 engineButtons += '<button title="Switch Engine" onclick="switchEngines('+"'"+engineKey+"'"+')" class="btn btn-'+warningLabel+' btn-sm">'+engineKey+'</button>';
#             };
#
#            $("#engineButtons9d85dfd3-6fd2-4169-a081-969b9d7b92ec").append(engineButtons);
#
#            $("#cancelQuery9d85dfd3-6fd2-4169-a081-969b9d7b92ec").on('click', function(){
#                if ($("#cancelQuery9d85dfd3-6fd2-4169-a081-969b9d7b92ec").hasClass('disabled')){
#                    console.log('alread stopped or finished query...');
#                } else {
#                    cancelQuery("dd642394-41b0-4494-b428-cb933a72f6ea");
#                    //$("#cancelQuery9d85dfd3-6fd2-4169-a081-969b9d7b92ec").addClass('disabled')
#                }
#            });
#
#             function explain(gloVar){
#                 var command =  `__SQLCell_GLOBAL_VARS__.`+gloVar+` = True`;
#                 console.log(command);
#                 var kernel = IPython.notebook.kernel;
#                 kernel.execute(command);
#                 IPython.notebook.execute_cell();
#             };
#
#             function run(){
#                 IPython.notebook.execute_cell();
#                 $.get('/api/contents', function(data){
#                     console.log(data);
#                 });
#             };
#
#             function cancelQuery(applicationID){
#                 IPython.notebook.kernel.execute('__SQLCell_GLOBAL_VARS__().kill_last_pid_on_new_thread(__SQLCell_GLOBAL_VARS__.jupyter_id, "econ", "9d85dfd3-6fd2-4169-a081-969b9d7b92ec")',
#                     {
#                         iopub: {
#                             output: function(response) {
#                                 var $table = $("#table9d85dfd3-6fd2-4169-a081-969b9d7b92ec").parent();
#                                 console.log(response);
#                                 if (response.content && response.content.text){
#                                     $table.append('<h5 style="color:#d9534f;">'+response.content.text+'</h5>')
#                                 } else if (response.content && response.content.evalue){
#                                     $table.append('<h5 style="color:#d9534f;">'+response.content.evalue+'</h5>');
#                                 }
#                             }
#                         }
#                     },
#                     {
#                         silent: false,
#                         store_history: false,
#                         stop_on_error: true
#                     }
#                 );
#             };
#
#             function getData(){
#                 var command = `__SQLCell_GLOBAL_VARS__.__GETDATA__ = True`;
#                 var kernel = IPython.notebook.kernel;
#                 kernel.execute(command);
#                 IPython.notebook.execute_cell();
#             };
#
#             function saveData(data, filename){
#                 var path = $('#path').val() || './'
#                 var command = `__SQLCell_GLOBAL_VARS__.__SAVEDATA__, PATH = True,'`+path+`'`;
#                 var kernel = IPython.notebook.kernel;
#                 kernel.execute(command);
#                 //IPython.notebook.execut

# %%
df = df.fillna(0)

# %% [markdown]
# # data dict look up

# %%
# data_dict_all[data_dict_all.field_value.astype(str).str.contains('OCCUPATION')]
data_dict_all[data_dict_all.field_name.astype(str).str.contains('HC03_VC87')]
# Out:
#    field_name  \
# 38  HC03_VC87
#
#                                                                                        field_value
# 38  Percent; EDUCATIONAL ATTAINMENT - Population 25 years and over - 9th to 12th grade, no diploma

# %%
df.head()
# Out:
#    sq_miles  HC03_VC96  HC01_VC03  HC01_VC103  HC03_VC67  HC03_VC68  \
# 0  4.439851  36.3       7013       1394        78.0       9.4
# 1  0.524270  56.9       10803      1562        87.6       8.0
# 2  4.944263  53.2       35893      4647        81.4       11.3
# 3  0.327078  80.9       16278      2673        88.3       7.8
# 4  0.678290  70.6       38752      6111        88.6       5.3
#
#    HC03_VC88  HC03_VC49  HC01_VC88  HC03_VC135  HC03_VC136  HC03_VC92  \
# 0  27.3       71.8       1677       1.3         27.3        14.0
# 1  11.9       73.9       668        1.7         20.6        24.5
# 2  10.9       75.4       7247       1.5         21.3        19.5
# 3  5.5        72.6       1120       1.5         31.9        36.9
# 4  9.7        72.5       6560       2.2         31.4        33.6
#
#    HC03_VC12  HC03_VC41  HC03_VC43  HC03_VC161  HC01_VC118  HC03_VC171    zip  \
# 0  9.8        34.4       19.6       11.3        56976       18.7        89109
# 1  6.1        61.3       19.8       10.7        62253       18.9        98101
# 2  7.6        56.0       22.0       11.8        49269       24.3        92101
# 3  3.6        69.7       22.9       5.3         104324      7.2         10017
# 4  6.1        68.5       19.0       8.1         86447       11.8        10019
#
#    grocery_stores  restaurants  manufacturing  tech  colleges  total  \
# 0  156             1536         24             13    32        2556
# 1  228             1124         36             49    80        2919
# 2  184             1828         8              22    208       3982
# 3  260             1344         20             52    240       4963
# 4  344             2192         24             35    232       4939
#
#    shopping_centers  new_homes  hotels  car_dealers  taxis  airport_related  \
# 0  15                18         90      9            6      2
# 1  22                12         162     3            3      4
# 2  38                62         273     3            15     30
# 3  104               34         582     3            6      11
# 4  70                46         699     30           39     5
#
#    starbucks_count  HC01_VC03_sqrt  num_of_sb       City State has_starbucks  \
# 0  25               83.743656       625        Las Vegas  NV    True
# 1  23               103.937481      529        Seattle    WA    True
# 2  23               189.454480      529        San Diego  CA    True
# 3  20               127.585266      400        New York   NY    True
# 4  17               196.855277      289        New York   NY    True
#
#    population_density
# 0  1579.557406
# 1  20605.800368
# 2  7259.524804
# 3  49767.876147
# 4  57131.899827

# %%
import statsmodels.formula.api as smf

mod = smf.ols(formula='starbucks_count ~ shopping_centers + tech + HC03_VC88 + airport_related + colleges', data=df)
# mod = smf.ols(formula='starbucks_count ~ shopping_centers + HC03_VC96 + HC03_VC161 + population_density', data=df)
res = mod.fit()
print res.summary()
# Out:
# DEBUG:root:Enter SimpleTable.data2rows.
# DEBUG:root:Exit SimpleTable.data2rows.
# DEBUG:root:Enter SimpleTable.data2rows.
# DEBUG:root:Exit SimpleTable.data2rows.
# DEBUG:root:Enter SimpleTable.data2rows.
# DEBUG:root:Exit SimpleTable.data2rows.
# DEBUG:root:Enter SimpleTable.data2rows.
# DEBUG:root:Exit SimpleTable.data2rows.
# DEBUG:root:Enter SimpleTable.data2rows.
# DEBUG:root:Exit SimpleTable.data2rows.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        starbucks_count   R-squared:                       0.514
# Model:                            OLS   Adj. R-squared:                  0.514
# Method:                 Least Squares   F-statistic:                     6876.
# Date:                Sat, 08 Apr 2017   Prob (F-statistic):               0.00
# Time:                        12:20:28   Log-Likelihood:                -36788.
# No. Observations:               32512   AIC:                         7.359e+04
# Df Residuals:                   32506   BIC:                         7.364e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------
# Intercept            0.2050      0.014     14.871      0.000         0.178     0.232
# shopping_centers     0.0443      0.002     25.170      0.000         0.041     0.048
# tech                 0.0129      0.001     15.871      0.000         0.011     0.014
# HC03_VC88           -0.0056      0.000    -15.655      0.000        -0.006    -0.005
# airport_related      0.0937      0.002     37.993      0.000         0.089     0.099
# colleges             0.0201      0.000     82.759      0.000         0.020     0.021
# ==============================================================================
# Omnibus:                    29748.242   Durbin-Watson:                   0.862
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          6348857.050
# Skew:                           3.782   Prob(JB):                         0.00
# Kurtosis:                      71.040   Cond. No.                         126.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
df['predict'] = res.predict(df[['shopping_centers','tech','HC03_VC88','airport_related','colleges']])

# %%
df.plot.scatter(x='predict', y='starbucks_count')
# Out:
# /usr/local/lib/python2.7/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
fig = pyplot.figure(figsize=(14,8)) # figure size
ax = fig.add_subplot(111) # axis information

# boxplot with only these two variables
# _ = df[['shopping_centers', 'has_starbucks']].boxplot(by='has_starbucks', figsize=(13,8), vert=False, sym='b.', ax=ax)
# _ = df[['new_homes', 'has_starbucks']].boxplot(by='has_starbucks', figsize=(13,8), vert=False, sym='b.', ax=ax)
# _ = df[['HC03_VC88', 'has_starbucks']].boxplot(by='has_starbucks', figsize=(13,8), vert=False, sym='b.', ax=ax)
_ = df[['HC03_VC96', 'has_starbucks']].boxplot(by='has_starbucks', figsize=(13,8), vert=False, sym='b.', ax=ax)

# %%
from statsmodels.regression.quantile_regression import QuantReg

# %%
df['has_starbuck_adj'] = df.has_starbucks.astype(int)

# %%
df_norm = (df - df.mean()) / (df.max() - df.min())

# %%
df.head()
# Out:
#    sq_miles  HC03_VC96  HC01_VC03  HC01_VC103  HC03_VC67  HC03_VC68  \
# 0  4.439851  36.3       7013       1394        78.0       9.4
# 1  0.524270  56.9       10803      1562        87.6       8.0
# 2  4.944263  53.2       35893      4647        81.4       11.3
# 3  0.327078  80.9       16278      2673        88.3       7.8
# 4  0.678290  70.6       38752      6111        88.6       5.3
#
#    HC03_VC88  HC03_VC49  HC01_VC88  HC03_VC135  HC03_VC136  HC03_VC92  \
# 0  27.3       71.8       1677       1.3         27.3        14.0
# 1  11.9       73.9       668        1.7         20.6        24.5
# 2  10.9       75.4       7247       1.5         21.3        19.5
# 3  5.5        72.6       1120       1.5         31.9        36.9
# 4  9.7        72.5       6560       2.2         31.4        33.6
#
#    HC03_VC12  HC03_VC41  HC03_VC43  HC03_VC161    zip  grocery_stores  \
# 0  9.8        34.4       19.6       11.3        89109  156
# 1  6.1        61.3       19.8       10.7        98101  228
# 2  7.6        56.0       22.0       11.8        92101  184
# 3  3.6        69.7       22.9       5.3         10017  260
# 4  6.1        68.5       19.0       8.1         10019  344
#
#    restaurants  manufacturing  tech  colleges  total  shopping_centers  \
# 0  1536         24             13    32        2556   15
# 1  1124         36             49    80        2919   22
# 2  1828         8              22    208       3982   38
# 3  1344         20             52    240       4963   104
# 4  2192         24             35    232       4939   70
#
#    new_homes  hotels  car_dealers  taxis  airport_related  starbucks_count  \
# 0  18         90      9            6      2                25
# 1  12         162     3            3      4                23
# 2  62         273     3            15     30               23
# 3  34         582     3            6      11               20
# 4  46         699     30           39     5                17
#
#    HC01_VC03_sqrt  num_of_sb has_starbucks
# 0  83.743656       625        True
# 1  103.937481      529        True
# 2  189.454480      529        True
# 3  127.585266      400        True
# 4  196.855277      289        True

# %%
res.predict(df[['shopping_centers','tech','HC03_VC88','hotels','colleges', 'airport_related']])
# Out:
# array([ 1.71347005,  3.72346179,  9.09517191, ...,  0.04232226,
#         0.51767204, -0.07339062])

# %%
mod = smf.quantreg('starbucks_count ~ shopping_centers + tech + HC03_VC88', df)
res = mod.fit(q=.5)
print(res.summary())
# Out:
# DEBUG:root:Enter SimpleTable.data2rows.
# DEBUG:root:Exit SimpleTable.data2rows.
# DEBUG:root:Enter SimpleTable.data2rows.
# DEBUG:root:Exit SimpleTable.data2rows.
# DEBUG:root:Enter SimpleTable.data2rows.
# DEBUG:root:Exit SimpleTable.data2rows.
#                          QuantReg Regression Results
# ==============================================================================
# Dep. Variable:        starbucks_count   Pseudo R-squared:               0.1434
# Model:                       QuantReg   Bandwidth:                   1.820e-08
# Method:                 Least Squares   Sparsity:                    3.005e-06
# Date:                Sat, 08 Apr 2017   No. Observations:                32512
# Time:                        12:23:17   Df Residuals:                    32508
#                                         Df Model:                            3
# ====================================================================================
#                        coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------
# Intercept         4.882e-08   2.57e-08      1.899      0.058     -1.57e-09  9.92e-08
# shopping_centers     0.1176    2.9e-09   4.06e+07      0.000         0.118     0.118
# tech                 0.0588   1.52e-09   3.87e+07      0.000         0.059     0.059
# HC03_VC88        -4.558e-09   6.86e-10     -6.643      0.000      -5.9e-09 -3.21e-09
# ====================================================================================

# %%
df['qr_predict'] = res.predict(df[['shopping_centers','tech','HC03_VC88']])

# %%
df[['qr_predict','starbucks_count']].plot()

# %%
import statsmodels.formula.api as smf

mod = smf.ols(formula='starbucks_count ~ grocery_stores + shopping_centers + HC03_VC161', data=df_)
res = mod.fit()
print res.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-632-cb9ecd612546> in <module>()
#       1 import statsmodels.formula.api as smf
#       2
# ----> 3 mod = smf.ols(formula='starbucks_count ~ grocery_stores + shopping_centers + HC03_VC161', data=df_)
#       4 res = mod.fit()
#       5 print res.summary()
#
# /Library/Python/2.7/site-packages/statsmodels/base/model.pyc in from_formula(cls, formula, data, subset, *args, **kwargs)
#     145         (endog, exog), missing_idx = handle_formula_data(data, None, formula,
#     146                                                          depth=eval_env,
# --> 147                                                          missing=missing)
#     148         kwargs.update({'missing_idx': missing_idx,
#     149                        'missing': missing})
#
# /Library/Python/2.7/site-packages/statsmodels/formula/formulatools.pyc in handle_formula_data(Y, X, formula, depth, missing)
#      63         if data_util._is_using_pandas(Y, None):
#      64             result = dmatrices(formula, Y, depth, return_type='dataframe',
# ---> 65                                NA_action=na_action)
#      66         else:
#      67             result = dmatrices(formula, Y, depth, return_type='dataframe',
#
# /usr/local/lib/python2.7/site-packages/patsy/highlevel.pyc in dmatrices(formula_like, data, eval_env, NA_action, return_type)
#     295     eval_env = EvalEnvironment.capture(eval_env, reference=1)
#     296     (lhs, rhs) = _do_highlevel_design(formula_like, data, eval_env,
# --> 297                                       NA_action, return_type)
#     298     if lhs.shape[1] == 0:
#     299         raise PatsyError("model is missing required outcome variables")
#
# /usr/local/lib/python2.7/site-packages/patsy/highlevel.pyc in _do_highlevel_design(formula_like, data, eval_env, NA_action, return_type)
#     150         return iter([data])
#     151     builders = _try_incr_builders(formula_like, data_iter_maker, eval_env,
# --> 152                                   NA_action)
#     153     if builders is not None:
#     154         return build_design_matrices(builders, data,
#
# /usr/local/lib/python2.7/site-packages/patsy/highlevel.pyc in _try_incr_builders(formula_like, data_iter_maker, eval_env, NA_action)
#      55                                        formula_like.rhs_termlist],
#      56                                       data_iter_maker,
# ---> 57                                       NA_action)
#      58     else:
#      59         return None
#
# /usr/local/lib/python2.7/site-packages/patsy/build.pyc in design_matrix_builders(termlists, data_iter_maker, NA_action)
#     658                                                    factor_states,
#     659                                                    data_iter_maker,
# --> 660                                                    NA_action)
#     661     # Now we need the factor evaluators, which encapsulate the knowledge of
#     662     # how to turn any given factor into a chunk of data:
#
# /usr/local/lib/python2.7/site-packages/patsy/build.pyc in _examine_factor_types(factors, factor_states, data_iter_maker, NA_action)
#     422     for data in data_iter_maker():
#     423         for factor in list(examine_needed):
# --> 424             value = factor.eval(factor_states[factor], data)
#     425             if factor in cat_sniffers or guess_categorical(value):
#     426                 if factor not in cat_sniffers:
#
# /usr/local/lib/python2.7/site-packages/patsy/eval.pyc in eval(self, memorize_state, data)
#     483     #    http://nedbatchelder.com/blog/200711/rethrowing_exceptions_in_python.html
#     484     def eval(self, memorize_state, data):
# --> 485         return self._eval(memorize_state["eval_code"], memorize_state, data)
#     486
#     487 def test_EvalFactor_basics():
#
# /usr/local/lib/python2.7/site-packages/patsy/eval.pyc in _eval(self, code, memorize_state, data)
#     466                                  self,
#     467                                  self._eval_env.eval,
# --> 468                                  code, inner_namespace=inner_namespace)
#     469
#     470     def memorize_chunk(self, state, which_pass, data):
#
# /usr/local/lib/python2.7/site-packages/patsy/compat.pyc in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#     115 def call_and_wrap_exc(msg, origin, f, *args, **kwargs):
#     116     try:
# --> 117         return f(*args, **kwargs)
#     118     except Exception as e:
#     119         if sys.version_info[0] >= 3:
#
# /usr/local/lib/python2.7/site-packages/patsy/eval.pyc in eval(self, expr, source_name, inner_namespace)
#     125         code = compile(expr, source_name, "eval", self.flags, False)
#     126         return eval(code, {}, VarLookupDict([inner_namespace]
# --> 127                                             + self._namespaces))
#     128
#     129     @classmethod
#
# <string> in <module>()
#
# NameError: name 'starbucks_count' is not defined
